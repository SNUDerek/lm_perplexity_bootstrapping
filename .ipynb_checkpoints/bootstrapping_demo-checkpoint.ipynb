# %% [markdown]
# # corpus bootstrapping with LM perplexity
#
# toy test of Ramaswamy, Printz, Gopalakrishnan: *A Bootstrap Technique for Building Domain-Dependent Langauge Models*
# http://mirlab.org/conference_papers/International_Conference/ICSLP%201998/PDF/SCAN/SL980611.PDF
#
# - uses simple bigram LM with add-k smoothing
# - in-domain data from Jane Austen
# - 'unlabeled' corpus of Austen,Carroll and Melville sentences

# %%
from collections import Counter
import math
import nltk
import random
import re

# %% [markdown]
# # in-domain corpus data
#
# load the three jane austen texts as tokenized sentences, preprocess (lowercase, remove punctuation etc, add `<s>` and `</s>` tags)

# %%
# read corpora
austen1 = nltk.corpus.gutenberg.sents('austen-emma.txt')
austen2 = nltk.corpus.gutenberg.sents('austen-persuasion.txt')
austen3 = nltk.corpus.gutenberg.sents('austen-sense.txt')
data = austen1 + austen2 + austen3
print(len(data))
# Out:
# 16498

# %%
# %%time
# shuffle data and withhold random set
indices = [i for i in range(len(data))]
random.shuffle(indices)
data = [data[i] for i in indices]

test_idx = int(len(data)*0.25)
corpus = data[:test_idx]
withheld = data[test_idx:]
data = None # clear
print(len(corpus), len(withheld))
# Out:
# 4124 12374
# CPU times: user 5.94 s, sys: 68 ms, total: 6.01 s
# Wall time: 6.02 s

# %% [markdown]
# ## preprocessing
#
# remove sents of len < 5 (words)

# %%
# %%time
# preprocess data (with function)
def preprocess(tokens):
    processed = []
    for sent in tokens:
        if len(sent) > 4:
            this_sent = []
            for word in sent:
                if re.findall(r'[0-9A-Za-z]+', word):
                    this_sent.append(word.lower())
            this_sent = ['<s>'] + this_sent + ['</s>']
            processed.append(this_sent)
    return processed
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 4.29 µs

# %%
corpus = preprocess(corpus)
withheld = preprocess(withheld)
print(len(corpus), len(withheld))
# Out:
# 3874 11584

# %% [markdown]
# # build bigram language model
#
# we will constuct this as a function so we can iterate

# %%
def languagemodel(corpus):
    
    # bigramize and get vocabulary
    bigrams = []
    vocab = []
    for sent in corpus:
        # split
        for i in range(len(sent)-1):
            vocab.append(sent[i])
            bigrams.append((sent[i], sent[i+1]))
        vocab.append(sent[-1])
        
    # get vocabulary size, counters
    # oovs will be handled by smoothing
    vocabsize = len(set(vocab))
    vocab_counts = Counter(vocab)
    bigram_counts = Counter(bigrams)
    
    return vocabsize, vocab_counts, bigram_counts

# %%
# %%time
vocabsize, vocab_counts, bigram_counts = languagemodel(corpus)
# Out:
# CPU times: user 76 ms, sys: 0 ns, total: 76 ms
# Wall time: 76.9 ms

# %% [markdown]
# # perplexity measurement
#
# this is a function of the probability of a given sentence under this language model's assumptions (i.e the product of the probability of each bigram normalized by the total sentence length)
#
# we use add-k smoothing to account for out-of-vocab terms

# %%
# perplexity calculation with add-k smoothing
# from http://www3.cs.stonybrook.edu/~has/CSE594/Notes/(1)%20Probability%20Theory%20Application%201-28.pdf
def perplexity(sent, k=0.1):
    # tokenize and bigramize
    bigrams = []
    for i in range(len(sent)-1):
        bigrams.append((sent[i], sent[i+1]))
        
    # for each bigram, get probability (add-one smoothed)
    # p(w_i | w_i-1) = count(w_i-1, w_i) + 1 / count(w_i-1 + N)
    probs = []
    for bigram in bigrams:
        b_c = bigram_counts[bigram] + k
        w_c = vocab_counts[bigram[0]] + k*vocabsize
        probs.append(b_c/w_c)
    
    # get inverse
    inverse = [1.0/prob for prob in probs]
    
    # get product
    product = 1.0
    for inv in inverse:
        product *= inv
    
    # n-th root
    perplexity = math.pow(product, (1/len(sent)))
    
    return perplexity

# %% [markdown]
# # external corpus
#
# this is data from an external source that (hopefully) includes some sentences that we can use for data augmentation.
#
# here we (artificially) create a mixed id/ood corpus by mixing our withheld data in with some text from another source. we will use moby dick because it is one of the NLTK prose texts closer in time to Jane Austen
#
# for testing, we will label each sentence according to source

# %%
withheld = [('austen', s) for s in withheld]
len(withheld)
# Out:
# 11584

# %%
melville = nltk.corpus.gutenberg.sents('melville-moby_dick.txt')
melville = preprocess(melville)
melville = [('melville', s) for s in melville]

carroll = nltk.corpus.gutenberg.sents('carroll-alice.txt')
carroll = preprocess(carroll)
carroll = [('carroll', s) for s in carroll]

len(melville), len(carroll)
# Out:
# (8857, 1514)

# %%
unlabeled = withheld + melville + carroll
len(unlabeled)
# Out:
# 21955

# %% [markdown]
# # sort by perplexity score
#
# as we can see, in-domain answers are at the top. of course it is not the case that necessarily all *(true)* in-domain sentences are at the top of the list.

# %%
# %%time
# get perplexities
perplexities = [perplexity(s[1]) for s in unlabeled]
# Out:
# CPU times: user 444 ms, sys: 0 ns, total: 444 ms
# Wall time: 444 ms

# %%
# sort by perplexity (lower = better)
[(x[0], ' '.join(x[1]), y) for x, y in sorted(zip(unlabeled, perplexities), key=lambda pair: pair[1])]
# Out:
# [('austen', '<s> i do not know </s>', 14.07823156249899),
#  ('austen', '<s> i do not know </s>', 14.07823156249899),
#  ('austen', '<s> i do not know </s>', 14.07823156249899),
#  ('austen', '<s> i am sure i do not know </s>', 16.591202304757346),
#  ('carroll', '<s> i had not </s>', 18.016593672744722),
#  ('austen', '<s> i have no doubt of it </s>', 18.7918527331002),
#  ('austen', '<s> i do not see it </s>', 19.83034646143901),
#  ('austen', '<s> she had seen him </s>', 19.967637510834614),
#  ('austen', '<s> she could not speak </s>', 20.54539305921532),
#  ('melville', '<s> i do as i do </s>', 21.180506693746803),
#  ('austen', '<s> i think it is so </s>', 21.471253413537685),
#  ('austen', '<s> i am glad of it </s>', 21.615284495399727),
#  ('austen', '<s> it must be so </s>', 22.072232527577608),
#  ('melville', '<s> but it is not so </s>', 22.333080733464396),
#  ('austen', '<s> i do not know my dear </s>', 22.465916566982422),
#  ('austen', '<s> i do not understand it </s>', 22.561024017428732),
#  ('melville', '<s> i am sure that i did not </s>', 22.999471201253254),
#  ('melville', '<s> i will tell you </s>', 23.640024683401553),
#  ('austen', '<s> i am very happy </s>', 23.69491182163105),
#  ('austen', '<s> to be sure </s>', 24.336279568317106),
#  ('austen', '<s> to be sure </s>', 24.336279568317106),
#  ('austen', '<s> to be sure </s>', 24.336279568317106),
#  ('austen', '<s> i am sure you will not like him </s>', 24.347595410774797),
#  ('melville', '<s> you must have heard of it </s>', 24.616741093233117),
#  ('austen', '<s> i am sure we do </s>', 24.711426804131285),
#  ('austen', '<s> they did not know </s>', 25.283661350349895),
#  ('austen', '<s> but it will not do </s>', 26.222113828402303),
#  ('austen', '<s> you are very good </s>', 26.281264257247468),
#  ('austen', '<s> i could not have believed it </s>', 27.035550864692205),
#  ('austen', '<s> i assure you i have </s>', 27.576444767229024),
#  ('austen', '<s> i am sure she does </s>', 27.89354439986491),
#  ('austen', '<s> i am sure i do not know who is not </s>', 28.541292708383125),
#  ('austen', '<s> yes i do </s>', 28.55951258821605),
#  ('austen', '<s> i should be sorry to be more </s>', 28.627792225726445),
#  ('austen', '<s> i have had such a time of it </s>', 28.65441289189094),
#  ('austen', '<s> i do not know what he would be at </s>', 28.826033287604908),
#  ('austen', '<s> but that would not do </s>', 29.799226786120304),
#  ('carroll', '<s> what is it </s>', 30.092418217778814),
#  ('austen', '<s> she had a great wish to see him </s>', 30.43901609481144),
#  ('austen', '<s> to be sure he is </s>', 30.606177847398197),
#  ('austen', '<s> that i am sure you would </s>', 30.8004459656806),
#  ('austen', '<s> not at all </s>', 31.234280053100175),
#  ('austen', '<s> not at all </s>', 31.234280053100175),
#  ('austen', '<s> to be sure i am </s>', 31.396725272434836),
#  ('austen', '<s> i know he did </s>', 31.428493932935417),
#  ('austen', '<s> i knew how it would be </s>', 31.429179114327482),
#  ('austen', '<s> i did not know what to do </s>', 31.624220012587333),
#  ('austen', '<s> i am sure you will agree with me </s>', 31.62789889686744),
#  ('austen', '<s> this must not be </s>', 32.0739904063949),
#  ('austen', '<s> my dear mrs </s>', 32.13476413098469),
#  ('austen', '<s> i am said he </s>', 32.19099195628158),
#  ('austen', '<s> i hope she is well </s>', 32.21727880807653),
#  ('austen', '<s> she must see you </s>', 32.58108755315795),
#  ('austen', '<s> there it is </s>', 32.60406767219397),
#  ('melville', '<s> i do sir </s>', 32.68427549846799),
#  ('austen', '<s> mr martin </s>', 32.70321623840186),
#  ('austen', '<s> my dear miss elliot </s>', 32.97227433945388),
#  ('austen', '<s> i assure you i shall not </s>', 33.07522847402115),
#  ('austen', '<s> mr knightley and jane fairfax </s>', 33.127635326773714),
#  ('austen', '<s> said mr weston </s>', 33.15287673938907),
#  ('austen', '<s> i am monstrous glad of it </s>', 33.412670051839974),
#  ('austen', '<s> i should be quite in the way </s>', 33.55511212266937),
#  ('austen', '<s> to be sure it would </s>', 33.81598716285986),
#  ('austen', '<s> she was not obliged to hear </s>', 34.08223428298708),
#  ('melville', '<s> i thought so </s>', 34.579475119038165),
#  ('austen', '<s> it is over </s>', 34.75969941164717),
#  ('austen', '<s> my dear miss dashwood </s>', 34.847562059750906),
#  ('austen', '<s> as a friend </s>', 34.92295601950788),
#  ('austen', '<s> i assure you she did </s>', 35.01771234708152),
#  ('austen', '<s> she would not look again </s>', 35.050786167916506),
#  ('austen', '<s> i do not pretend to it </s>', 35.0778030930227),
#  ('austen', '<s> she hoped it was not so </s>', 35.12540351005702),
#  ('austen', '<s> but it was too late </s>', 35.172717178819234),
#  ('austen', '<s> i should wish it </s>', 35.27294902387121),
#  ('melville', '<s> and what is it </s>', 35.50537940733406),
#  ('austen', '<s> it was not in her nature </s>', 35.9555495673262),
#  ('melville', '<s> do with it </s>', 36.00283028974263),
#  ('austen', '<s> that i had never seen her </s>', 36.16341691131428),
#  ('austen', '<s> but i thought you would </s>', 36.23563274102379),
#  ('austen', '<s> yes he had done it </s>', 36.30262122255702),
#  ('austen', '<s> to be sure it will </s>', 36.69106625658717),
#  ('austen', '<s> said mrs dashwood </s>', 36.77387347620529),
#  ('melville', '<s> but this is not all </s>', 36.877336620450606),
#  ('melville', '<s> but this is not all </s>', 36.877336620450606),
#  ('austen',
#   '<s> they will be so very happy to see you </s>',
#   37.327466657874496),
#  ('austen', '<s> i shall never forget it </s>', 37.55483760804666),
#  ('austen',
#   '<s> i dare say she did not understand me </s>',
#   37.569554740310856),
#  ('austen', '<s> dear mrs weston </s>', 37.71082495424741),
#  ('austen', '<s> she could not stand it </s>', 37.816935783202105),
#  ('austen', '<s> emma could not doubt </s>', 37.96063847905943),
#  ('austen', '<s> she is not satisfied </s>', 38.019831360538106),
#  ('austen', '<s> do you think it is a good one </s>', 38.124485101001774),
#  ('austen', '<s> you are so kind </s>', 38.19576200945426),
#  ('austen', '<s> i am extremely happy </s>', 38.36678835628422),
#  ('melville', '<s> i want to see the world </s>', 38.74704775214466),
#  ('austen', '<s> cried mr knightley </s>', 38.8184975639755),
#  ('austen', '<s> i am quite ready </s>', 38.93527718454865),
#  ('melville', '<s> what do you think </s>', 39.16829209879265),
#  ('austen', '<s> i am sick of it </s>', 39.24326107897575),
#  ('austen', '<s> but miss bates and miss fairfax </s>', 39.247851761879254),
#  ('melville', '<s> and so it was </s>', 39.29350923472159),
#  ('austen', '<s> no indeed </s>', 39.36012955672861),
#  ('austen', '<s> she was not sorry </s>', 39.37874377682425),
#  ('austen', '<s> i am sorry for it </s>', 39.447384799107766),
#  ('austen', '<s> it was a commission to me </s>', 39.736941362583316),
#  ('austen', '<s> i am always glad to see him </s>', 39.99901308814773),
#  ('austen',
#   '<s> i am glad i did not think of it before </s>',
#   40.18109908541019),
#  ('austen', '<s> no indeed i do not </s>', 40.21406303730199),
#  ('carroll', '<s> what was that </s>', 40.30186682306767),
#  ('melville', '<s> i would not take it </s>', 40.31862182243863),
#  ('austen', '<s> i shall soon have done </s>', 40.41658464896917),
#  ('austen', '<s> there is nothing in that </s>', 40.465347154886864),
#  ('austen', '<s> the best of all </s>', 40.73258373514748),
#  ('austen', '<s> she must understand you </s>', 40.804330652196356),
#  ('austen', '<s> they would be very much pleased </s>', 40.81667183718273),
#  ('austen', '<s> what is all this </s>', 41.20081158989874),
#  ('austen', '<s> it was no more than a wish </s>', 41.25097618510274),
#  ('austen', '<s> it was not lost on me </s>', 41.38053581424384),
#  ('austen', '<s> it had been in situation </s>', 41.42691227643536),
#  ('austen', '<s> do you i have no doubt </s>', 41.54470528744767),
#  ('melville', '<s> it is his </s>', 41.639134193763844),
#  ('melville', '<s> it is his </s>', 41.639134193763844),
#  ('melville', '<s> it is his </s>', 41.639134193763844),
#  ('melville', '<s> it is his </s>', 41.639134193763844),
#  ('melville', '<s> it is his </s>', 41.639134193763844),
#  ('austen', '<s> to be sure you did </s>', 41.80751449868739),
#  ('austen', '<s> it is very natural </s>', 41.86673562880629),
#  ('austen', '<s> she could not stay </s>', 41.978447017456446),
#  ('austen', '<s> no indeed it is not </s>', 41.98290737388812),
#  ('austen', '<s> it is my party </s>', 42.01404441124764),
#  ('austen', '<s> i shall not stop </s>', 42.20094748572927),
#  ('austen', '<s> you are always with me </s>', 42.58549606844766),
#  ('austen', '<s> i believe she does </s>', 43.237018813198254),
#  ('austen',
#   '<s> i am sure she is very good i hope she will be very happy </s>',
#   43.32710157146327),
#  ('austen', '<s> you are right </s>', 43.34728413216338),
#  ('austen', '<s> you are right </s>', 43.34728413216338),
#  ('austen', '<s> he would be so very </s>', 43.5365142558817),
#  ('austen',
#   '<s> i know you will not be sorry to be off </s>',
#   43.56094633627401),
#  ('austen', '<s> and i am sure sir </s>', 43.655575231704354),
#  ('melville', '<s> but no more of this </s>', 43.9444627160293),
#  ('austen', '<s> i am not going to marry mr elliot </s>', 43.96334936839184),
#  ('austen',
#   '<s> i am sure she will be pleased with the children </s>',
#   44.030132624085134),
#  ('austen', '<s> it was enough for her to feel </s>', 44.08418889156871),
#  ('austen', '<s> and this was the end of it </s>', 44.21421800843967),
#  ('austen', '<s> do you think so </s>', 44.2651850485018),
#  ('austen', '<s> do you think so </s>', 44.2651850485018),
#  ('austen', '<s> very happy to hear it </s>', 44.35672381092829),
#  ('austen', '<s> you are acquainted with him </s>', 44.61651021958942),
#  ('austen',
#   '<s> i have no idea of that sort of thing </s>',
#   44.80468513481452),
#  ('austen', '<s> who could have thought it </s>', 44.81700117465407),
#  ('austen', '<s> dear miss woodhouse </s>', 44.9661092034216),
#  ('austen', '<s> what do you mean </s>', 45.02994569541945),
#  ('austen', '<s> what do you mean </s>', 45.02994569541945),
#  ('austen', '<s> it was a very extraordinary thing </s>', 45.273915890036),
#  ('austen', '<s> i have thought only of you </s>', 45.400582012219076),
#  ('austen', '<s> very well i am much obliged to you </s>', 45.44166694136278),
#  ('austen', '<s> i do not dislike him </s>', 45.521546491634034),
#  ('austen', '<s> but so it was </s>', 45.67376493071084),
#  ('austen', '<s> but how shall i do </s>', 45.88752262568073),
#  ('melville', '<s> it is man </s>', 45.91467474667489),
#  ('austen', '<s> mr elton is going to be married </s>', 46.04670427306048),
#  ('austen', '<s> what can be the meaning of it </s>', 46.225719844927454),
#  ('austen', '<s> that is a good thing </s>', 46.24066146346649),
#  ('austen', '<s> nothing at all </s>', 46.26274915388472),
#  ('austen', '<s> i am quite enough in love </s>', 46.31005248960031),
#  ('austen', '<s> with all my heart </s>', 46.465872262775456),
#  ('austen', '<s> with all my heart </s>', 46.465872262775456),
#  ('austen', '<s> emma could say no more </s>', 46.49237688839629),
#  ('austen', '<s> i could not have stood it </s>', 46.54247762810544),
#  ('austen', '<s> you think so do not you </s>', 46.58434655836163),
#  ('austen', '<s> do not you think so </s>', 46.676228536855184),
#  ('austen', '<s> so very kind </s>', 46.889840982746655),
#  ('austen',
#   '<s> it would be impossible to go to morrow </s>',
#   47.038997047294586),
#  ('austen', '<s> you must have done well </s>', 47.07864560009527),
#  ('austen', '<s> said emma as soon as she could speak </s>', 47.1108492436532),
#  ('austen', '<s> i like him very well </s>', 47.38211791752535),
#  ('austen',
#   '<s> i have no doubt of his being a most amiable young man </s>',
#   47.64573105980674),
#  ('austen', '<s> he had better not be in a hurry </s>', 47.69151349760168),
#  ('austen',
#   '<s> i am glad i have done being in love with him </s>',
#   47.727909260863434),
#  ('austen', '<s> poor jane fairfax </s>', 47.79132588172539),
#  ('melville', '<s> do i suppose it </s>', 47.84791732459656),
#  ('austen', '<s> so much the better </s>', 48.09223203222705),
#  ('austen', '<s> elinor would not speak </s>', 48.17631831909603),
#  ('austen', '<s> he is so very superior </s>', 48.2229010231513),
#  ('austen', '<s> she was perfectly convinced of it </s>', 48.24453202631873),
#  ('austen', '<s> you are very wrong </s>', 48.25859826904361),
#  ('austen', '<s> i am afraid none at all </s>', 48.41994487214354),
#  ('austen', '<s> poor mr elton </s>', 48.462311941422435),
#  ('austen', '<s> there is no hurry at all </s>', 48.54636431835894),
#  ('austen', '<s> no no </s>', 48.904822931170905),
#  ('carroll', '<s> no no </s>', 48.904822931170905),
#  ('carroll', '<s> no no </s>', 48.904822931170905),
#  ('melville', '<s> yes but i should like to see him </s>', 48.9633775969976),
#  ('austen', '<s> how do you like them </s>', 49.05826880348413),
#  ('austen', '<s> my dear madam </s>', 49.34212685864201),
#  ('austen', '<s> no indeed i have not </s>', 49.34551700637147),
#  ('austen', '<s> it is he it is indeed i know it is </s>', 49.42061243223863),
#  ('austen', '<s> i was not aware of it myself </s>', 49.476039079728075),
#  ('austen', '<s> i could have no other pleasure </s>', 49.59172223523788),
#  ('austen',
#   '<s> i have a great curiosity to see mrs elton i have heard so much of her </s>',
#   49.62638952086626),
#  ('austen', '<s> you do not mean it </s>', 49.63687683371944),
#  ('carroll', '<s> why should it </s>', 49.73823028920716),
#  ('austen', '<s> i assure you it is not in my power </s>', 49.84224148445993),
#  ('austen', '<s> yes said emma i hope i do </s>', 49.91209126909466),
#  ('austen', '<s> elinor said no more </s>', 49.9515806844566),
#  ('austen', '<s> she would indeed </s>', 49.99843129891548),
#  ('austen', '<s> how can you think of such a thing </s>', 50.04402658727735),
#  ('austen', '<s> elinor i must go home </s>', 50.06312443508896),
#  ('austen', '<s> i am going to kingston </s>', 50.20169077751053),
#  ('austen', '<s> what can it be </s>', 50.335085296144335),
#  ('austen', '<s> i am not at all equal to it </s>', 50.39127666819295),
#  ('austen', '<s> yes i would </s>', 50.50581506808178),
#  ('austen', '<s> it came from mr elliot </s>', 50.67345276378017),
#  ('austen',
#   '<s> sir john could not have thought it possible </s>',
#   50.72114938667034),
#  ('austen', '<s> no indeed i am not </s>', 50.75682851260502),
#  ('austen',
#   '<s> but you have not seen so much of the world as i have </s>',
#   50.80317738041515),
#  ('melville', '<s> he must have more than that </s>', 51.01694530552623),
#  ('austen',
#   '<s> i see you know nothing of the matter </s>',
#   51.330531916026125),
#  ('austen', '<s> mr elton going to be married </s>', 51.5960783901393),
#  ('austen', '<s> i am very much astonished mr elton </s>', 51.70411761239416),
#  ('austen', '<s> her father and harriet </s>', 51.72039772788916),
#  ('austen', '<s> he is so droll </s>', 51.80919990443382),
#  ('melville', '<s> how was it </s>', 51.82226868276191),
#  ('austen', '<s> mr ferrars is to be the man </s>', 51.85445093543016),
#  ('austen', '<s> what is mr elliot to me </s>', 51.872190874936216),
#  ('austen', '<s> i am so glad to see you </s>', 51.8993704338305),
#  ('austen', '<s> i was not at all aware of this </s>', 52.12052057404098),
#  ('austen', '<s> that is very likely </s>', 52.140186308160416),
#  ('austen', '<s> yes that i do indeed </s>', 52.21816512779058),
#  ('austen', '<s> what is this </s>', 52.25776133044118),
#  ('austen', '<s> he came to them every day </s>', 52.673093059556116),
#  ('austen',
#   '<s> you will be delighted with them i am sure </s>',
#   52.84137538949671),
#  ('austen', '<s> they will hear you </s>', 52.87737902816201),
#  ('austen', '<s> mr frank churchill did not come </s>', 52.89198712561222),
#  ('austen',
#   '<s> such a friend as mrs weston was out of the question </s>',
#   53.17509378552976),
#  ('austen',
#   '<s> i am a little acquainted with captain benwick </s>',
#   53.18685917421141),
#  ('austen', '<s> i can give you no account of them </s>', 53.41843536177939),
#  ('austen', '<s> i like him very much </s>', 53.480283968080215),
#  ('austen', '<s> what was his name </s>', 53.55136705930065),
#  ('austen', '<s> he certainly did </s>', 53.67723465040313),
#  ('austen', '<s> i wish she had accepted him </s>', 53.69681612695321),
#  ('austen', '<s> it is very pretty said mr woodhouse </s>', 53.73287201862634),
#  ('austen',
#   '<s> i am sure she will be here presently </s>',
#   53.895791314309164),
#  ('austen',
#   '<s> but you are too good for that i am sure </s>',
#   53.92580672441052),
#  ('austen',
#   '<s> mrs weston had been speaking to her at the same moment </s>',
#   54.23372596030833),
#  ('austen', '<s> but what shall i say </s>', 54.25547722362672),
#  ('austen', '<s> yes ma am </s>', 54.33303769501391),
#  ('austen', '<s> you may see the end of the house </s>', 54.44139121530605),
#  ('austen',
#   '<s> a very agreeable young man to be sure i know him very well </s>',
#   54.489060802625055),
#  ('austen',
#   '<s> she was not to see frank churchill this morning </s>',
#   54.51713881578392),
#  ('austen',
#   '<s> yes said john knightley and i think we shall have a good deal of it </s>',
#   54.5778421413253),
#  ('austen', '<s> i have had no hand in it </s>', 54.65758152083868),
#  ('austen', '<s> it will be the only difference </s>', 54.68090714089885),
#  ('austen', '<s> her father and mother </s>', 54.70602142490253),
#  ('carroll', '<s> who are you </s>', 54.766136486324875),
#  ('carroll', '<s> who are you </s>', 54.766136486324875),
#  ('austen',
#   '<s> i have no doubt of his being a very respectable young man </s>',
#   54.76948345255064),
#  ('austen', '<s> so far it is very true </s>', 54.882362552325674),
#  ('austen', '<s> mr elton indeed </s>', 54.9207606891512),
#  ('austen', '<s> what a very good looking man </s>', 54.958584536870546),
#  ('carroll', '<s> the other side of what </s>', 55.117177887425804),
#  ('austen', '<s> no ma am </s>', 55.13965691946923),
#  ('austen', '<s> your sister s marriage </s>', 55.175136560818686),
#  ('austen',
#   '<s> knightley i could not have believed it </s>',
#   55.27088102483982),
#  ('austen',
#   '<s> i have a great curiosity to know what mr elliot was as a very young man </s>',
#   55.35402277676492),
#  ('austen', '<s> she could not be deceived in that </s>', 55.357178664874525),
#  ('austen', '<s> it is not willoughby </s>', 55.40066703969051),
#  ('austen', '<s> they were obliged to move </s>', 55.43281396967793),
#  ('austen', '<s> it is his own idea </s>', 56.202522892341555),
#  ('austen', '<s> she assured him that she had not </s>', 56.23617563571034),
#  ('austen',
#   '<s> i dare say you are and i am sure i do not at all wonder at it </s>',
#   56.2386020078558),
#  ('austen', '<s> i have engaged captain wentworth </s>', 56.269880825455544),
#  ('austen', '<s> mr woodhouse told me of it </s>', 56.27942671004626),
#  ('austen',
#   '<s> he will be here in a moment i am sure </s>',
#   56.530387217330194),
#  ('austen', '<s> but it should be so no more </s>', 56.56373601734985),
#  ('melville', '<s> oh the world </s>', 56.69424588728639),
#  ('austen', '<s> no nothing at all </s>', 56.722328287375966),
#  ('austen',
#   '<s> we must go in the carriage to be sure </s>',
#   56.78888853987665),
#  ('carroll', '<s> she knows such a very little </s>', 56.85291416030623),
#  ('austen', '<s> you will excuse me </s>', 56.91231128288176),
#  ('austen',
#   '<s> you will not like him i will answer for it </s>',
#   57.08305508986976),
#  ('austen', '<s> do not you pity me </s>', 57.285146996378494),
#  ('austen', '<s> oh elinor </s>', 57.52711818338277),
#  ('melville', '<s> this is what i mean </s>', 57.607980120920466),
#  ('austen',
#   '<s> she had no scruple with regard to him </s>',
#   57.706072298557054),
#  ('austen', '<s> what shall you do </s>', 57.80060074490382),
#  ('austen', '<s> what is the matter </s>', 57.928637129491506),
#  ('austen', '<s> i hope i can allow for him </s>', 58.0296037364228),
#  ('carroll', '<s> you are not attending </s>', 58.10722280147013),
#  ('austen', '<s> i dare say she had </s>', 58.11586070963478),
#  ('austen',
#   '<s> but i am afraid and i should be so very sorry </s>',
#   58.28816676769277),
#  ('austen', '<s> it was a bad business </s>', 58.36176358189305),
#  ('melville', '<s> what is it more </s>', 58.40547831009306),
#  ('austen', '<s> i did not see you before </s>', 58.44744983858429),
#  ('austen',
#   '<s> i am sure edward ferrars is not well </s>',
#   58.47070930955311),
#  ('austen',
#   '<s> i do not know which it ought to be called </s>',
#   58.505024808597),
#  ('austen', '<s> what do you say to mrs </s>', 58.508831871334046),
#  ('austen',
#   '<s> i must confess it is a recommendation to me </s>',
#   58.5455283781148),
#  ('austen', '<s> cried mrs jennings </s>', 58.846937124304304),
#  ('austen',
#   '<s> i have heard him say that he could listen to her for ever </s>',
#   58.89378175034991),
#  ('austen', '<s> you will not find her there </s>', 58.95746136338269),
#  ('austen', '<s> i was there one of the party </s>', 59.15398952194509),
#  ('austen', '<s> it really was so </s>', 59.18789143043983),
#  ('austen', '<s> i would have her understand me </s>', 59.2539951339506),
#  ('austen', '<s> i am quite determined to refuse him </s>', 59.28258262326444),
#  ('austen', '<s> mrs weston would be at ease </s>', 59.293975469759495),
#  ('austen', '<s> no i thank you </s>', 59.30717486696561),
#  ('austen',
#   '<s> she felt a great deal of good will towards him </s>',
#   59.407174535277626),
#  ('austen', '<s> it is such a blessing </s>', 59.445846519806466),
#  ('austen', '<s> i know we shall be happy </s>', 59.4876800660225),
#  ('austen',
#   '<s> certainly he is not like mr knightley </s>',
#   59.492110349049206),
#  ('melville', '<s> what is the matter with me </s>', 59.515613592854976),
#  ('carroll', '<s> i beg your pardon </s>', 59.53866160929883),
#  ('austen',
#   '<s> you know him then said mrs dashwood </s>',
#   59.558568307616184),
#  ('austen', '<s> she had no objection </s>', 59.616101273300416),
#  ('austen', '<s> she would be very glad to stay </s>', 59.66131137674758),
#  ('austen', '<s> there i was quite right </s>', 59.671520186616576),
#  ('carroll', '<s> i think that will be the best plan </s>', 59.70461201027565),
#  ('austen',
#   '<s> and now to be sure you will be in no hurry to be gone </s>',
#   59.72627707586795),
#  ('carroll', '<s> what do you mean by that </s>', 59.78457204135036),
#  ('austen', '<s> he is a most fortunate man </s>', 59.79696275580657),
#  ('austen', '<s> perhaps i shall </s>', 59.8844561078898),
#  ('austen', '<s> he did not come however </s>', 60.171450849260225),
#  ('austen',
#   '<s> i dare say mr knightley will be so kind as to meet him </s>',
#   60.2639559967135),
#  ('austen', '<s> she could say nothing </s>', 60.578724275670034),
#  ('austen',
#   '<s> i was to decide on the best of them </s>',
#   60.613334119616084),
#  ('melville', '<s> tell me that mr </s>', 60.75781677031898),
#  ('austen',
#   '<s> there could be no doubt of his being a sensible man </s>',
#   60.861764303815995),
#  ('austen', '<s> this was the fact </s>', 60.90602646643313),
#  ('austen', '<s> well she is to marry him </s>', 60.92228249247504),
#  ('austen', '<s> but mr elliot was not done with </s>', 61.23396794585165),
#  ('austen', '<s> oh yes i dare say you will </s>', 61.32553533154938),
#  ('austen', '<s> i wonder whether it is so </s>', 61.37661642924745),
#  ('austen', '<s> i cannot doubt it </s>', 61.433988262214484),
#  ('austen', '<s> do not you anne </s>', 61.43943471365109),
#  ('austen', '<s> i hope they are quite well </s>', 61.49429857774776),
#  ('austen', '<s> that s all </s>', 61.654554724995485),
#  ('carroll', '<s> that s all </s>', 61.654554724995485),
#  ('austen',
#   '<s> i have no doubt of it replied marianne </s>',
#   61.70635538505339),
#  ('austen',
#   '<s> there is nothing to be compared to it </s>',
#   61.81062383737275),
#  ('austen',
#   '<s> but i have no reason to suppose it so </s>',
#   61.86016340501684),
#  ('austen', '<s> she is always so attentive to them </s>', 61.99922628660123),
#  ('austen', '<s> i never could have supposed it </s>', 62.059459947478345),
#  ('austen', '<s> it was a right thing to do </s>', 62.10300365191082),
#  ('austen', '<s> but what is the meaning of this </s>', 62.29004330289244),
#  ('austen', '<s> but could it be so </s>', 62.390881276773946),
#  ('austen', '<s> i could do very well without it </s>', 62.610989398600324),
#  ('austen', '<s> i think we must get him to bath </s>', 62.6334096946107),
#  ('melville', '<s> what do you know about him </s>', 62.7374694606719),
#  ('melville', '<s> it was he it was he </s>', 62.741071176367896),
#  ('austen',
#   '<s> i never had the smallest i assure you </s>',
#   62.80027231590302),
#  ('austen', '<s> but in time they will </s>', 62.81225722002657),
#  ('austen',
#   '<s> in the way of love i am sure he does not </s>',
#   62.851573247099644),
#  ('carroll', '<s> it is a very good height indeed </s>', 63.0423046241008),
#  ('austen', '<s> not to my feelings </s>', 63.14813378607787),
#  ('austen',
#   '<s> no i do not that is i do not mean what shall i do </s>',
#   63.16166679120975),
#  ('austen', '<s> i cannot agree with you </s>', 63.222470731534415),
#  ('austen', '<s> how do you do very well i thank you </s>', 63.25667517153676),
#  ('austen', '<s> emma my dear emma </s>', 63.61367725232939),
#  ('austen',
#   '<s> said miss steele as soon as they were gone </s>',
#   63.62305718681967),
#  ('austen', '<s> i understand you said elinor </s>', 63.62887918216257),
#  ('austen',
#   '<s> they had been once more in the same room </s>',
#   63.641115824527354),
#  ('austen',
#   '<s> and that i fancy will be the end of it </s>',
#   63.69371190859356),
#  ('carroll', '<s> one side of what </s>', 63.800407976149046),
#  ('austen',
#   '<s> they had no inclination to listen to her </s>',
#   63.81255600296749),
#  ('melville', '<s> it has happened before </s>', 63.84371843578526),
#  ('austen', '<s> he might observe that it was so </s>', 63.88425537238025),
#  ('austen',
#   '<s> indeed that must be a very great pleasure </s>',
#   63.9224863875125),
#  ('austen', '<s> do not run away with such an idea </s>', 63.972024295102656),
#  ('austen', '<s> but i ought to have gone before </s>', 64.17252497935947),
#  ('austen', '<s> i would do more than for my own </s>', 64.24005586328391),
#  ('austen', '<s> a great many things i assure you </s>', 64.24433699915075),
#  ('austen', '<s> i shall never forget his happiness </s>', 64.33818744878882),
#  ('austen', '<s> i really could not help exclaiming </s>', 64.4697863692095),
#  ('austen', '<s> i do not believe i did you any good </s>', 64.47159752758502),
#  ('melville', '<s> what s that he said </s>', 64.49241496532221),
#  ('austen',
#   '<s> i am sorry mr and mrs cole should have done it </s>',
#   64.88324649165145),
#  ('austen', '<s> she wanted to be alone </s>', 64.98754393182533),
#  ('austen',
#   '<s> i wish you had been there to see her behaviour </s>',
#   65.03286803880752),
#  ('austen', '<s> he ought to come said emma </s>', 65.05627132767317),
#  ('melville', '<s> it was the while </s>', 65.09197599092734),
#  ('carroll', '<s> what s in it </s>', 65.22746731100122),
#  ('austen',
#   '<s> in the mean while she was in the carriage </s>',
#   65.37009901963201),
#  ('austen',
#   '<s> i know they will but i am sure i would not do such a thing for all the world la </s>',
#   65.67672669563581),
#  ('austen', '<s> she has a fault </s>', 65.69332221176501),
#  ('austen', '<s> and you can be always with me </s>', 65.85101008571542),
#  ('austen', '<s> you must have seen that i did </s>', 65.9690829376357),
#  ('austen', '<s> no i did not promise </s>', 65.97604399189657),
#  ('austen', '<s> we are assured of it </s>', 66.07999387586482),
#  ('austen',
#   '<s> what a very great pleasure it will be to you </s>',
#   66.18239277576092),
#  ('austen',
#   '<s> i began to think i should never see you </s>',
#   66.30608879912974),
#  ('austen', '<s> she hardly knew what to say </s>', 66.35883895443322),
#  ('austen', '<s> oh did not you </s>', 66.42063549535473),
#  ('austen',
#   '<s> what is to be done my dear emma what is to be done </s>',
#   66.46628553887255),
#  ('austen', '<s> i thought you meant to go with me </s>', 66.47666541649693),
#  ('austen', '<s> and what sort of a young man is he </s>', 66.5917695241518),
#  ('austen', '<s> you saw what she said </s>', 66.6318279284054),
#  ('austen',
#   '<s> it would not be a bad thing for her to be very much in love with a proper object </s>',
#   66.63823789844437),
#  ('austen', '<s> he shook his head </s>', 66.90001560190326),
#  ('austen', '<s> to be sure i did very often </s>', 66.92367932456662),
#  ('austen', '<s> you know who i mean </s>', 66.96817667159156),
#  ('austen', '<s> not at all i believe with you </s>', 67.12357651749782),
#  ('austen',
#   '<s> he seemed to me very well off as he was </s>',
#   67.13441789949867),
#  ('austen',
#   '<s> i am sure i had much rather hear you </s>',
#   67.19890132465432),
#  ('austen',
#   '<s> emma had not been thinking of him she had forgotten to think of him but she was very glad to see him </s>',
#   67.21823671748177),
#  ('austen', '<s> but how can it be done </s>', 67.25908765738514),
#  ('austen', '<s> she was in good humour with all </s>', 67.28227804754943),
#  ('austen', '<s> now will be the time </s>', 67.3171266532133),
#  ('austen', '<s> every thing so good </s>', 67.43128568369349),
#  ('austen', '<s> they are not far off </s>', 67.5098692194379),
#  ('melville', '<s> no no no </s>', 67.5124265514726),
#  ('austen',
#   '<s> you look as if you would not do such a thing again </s>',
#   67.62542265595751),
#  ('austen', '<s> and it was soon over </s>', 67.62800928017005),
#  ('austen', '<s> i could not answer it </s>', 67.659080808804),
#  ('austen', '<s> and to what part of it </s>', 67.82326722120699),
#  ('austen', '<s> i am almost ashamed to say it </s>', 67.89686432591658),
#  ('melville', '<s> i must have partners </s>', 67.98001986082951),
#  ('austen', '<s> it is so ridiculous </s>', 68.15050560612111),
#  ('austen', '<s> to be sure so it is </s>', 68.21279560718139),
#  ('austen',
#   '<s> i found he had been used to hear of me </s>',
#   68.23928473084469),
#  ('austen', '<s> yes very soon </s>', 68.59730997745233),
#  ('austen', '<s> do look at it </s>', 68.6626489621202),
#  ('carroll', '<s> what was that like </s>', 68.77015605816591),
#  ('austen', '<s> is not it so </s>', 68.81805798265567),
#  ('austen',
#   '<s> he asked me if he could do any thing </s>',
#   68.95199943402271),
#  ('austen', '<s> and so you are forced to do it </s>', 68.9523642809805),
#  ('austen', '<s> she must not walk </s>', 69.0480725486831),
#  ('austen', '<s> i do not admire it said mr knightley </s>', 69.1376263919827),
#  ('austen',
#   '<s> she thought of her father of lady russell </s>',
#   69.17702404476059),
#  ('austen',
#   '<s> there will not be time for any thing </s>',
#   69.22420468534362),
#  ('austen', '<s> he told me the whole story </s>', 69.25519494693067),
#  ('austen', '<s> a bad thing </s>', 69.32295929544344),
#  ('austen', '<s> i wonder what it can be </s>', 69.37077995110613),
#  ('austen',
#   '<s> mr elton in love with me what an idea </s>',
#   69.39439883914036),
#  ('austen',
#   '<s> said i it is miss woodhouse i am sure you will like to see her </s>',
#   69.43048281375916),
#  ('austen',
#   '<s> but i am very much and without being at all ashamed of it </s>',
#   69.54758605099413),
#  ('melville', '<s> there you have him </s>', 69.61789835582702),
#  ('austen', '<s> mrs weston wants to see you </s>', 69.78455104966869),
#  ('austen',
#   '<s> she and mr frank churchill had been at weymouth at the same time </s>',
#   69.8048207077562),
#  ('austen', '<s> yes i should i am sure i should </s>', 69.84412202231735),
#  ('austen', '<s> i am in no hurry </s>', 69.85418219488413),
#  ('austen', '<s> mr elton was only too happy </s>', 69.85631893083794),
#  ('austen',
#   '<s> it would have been very unpleasant to me in every respect </s>',
#   69.86404195384914),
#  ('austen',
#   '<s> i hope it is not to say that your sister is worse </s>',
#   69.94548909643939),
#  ('melville', '<s> i think so sir </s>', 69.97952596867722),
#  ('austen', '<s> he had time only to say </s>', 70.15943727645576),
#  ('austen', '<s> the crofts must be in bath </s>', 70.16932425344092),
#  ('carroll', '<s> i can hardly breathe </s>', 70.27971830258717),
#  ('austen', '<s> said almost every body </s>', 70.28956781765825),
#  ('austen', '<s> it is a melancholy consideration </s>', 70.32960535416885),
#  ('austen', '<s> how is it possible </s>', 70.3640804725318),
#  ('austen', '<s> she is a sweet creature </s>', 70.4978911892953),
#  ('austen', '<s> i am a great dreamer </s>', 70.5239795631056),
#  ('austen', '<s> how do you do my dear </s>', 70.57275064579254),
#  ('austen', '<s> why should you think so </s>', 70.74044675146565),
#  ('austen', '<s> he is going to kingston </s>', 70.7588735005589),
#  ('austen', '<s> she had rather play </s>', 70.78685670913157),
#  ('austen',
#   '<s> there could be no doubt of his great pleasure in seeing her </s>',
#   70.85210972379599),
#  ('austen',
#   '<s> i do not think it could disagree with you </s>',
#   71.27228185677254),
#  ('austen', '<s> can you indeed </s>', 71.31229341471922),
#  ('austen', '<s> we are never safe from him </s>', 71.325051929427),
#  ('austen',
#   '<s> this was very kind of you to be persuaded to come </s>',
#   71.46905600952947),
#  ('melville', '<s> what do you want of me </s>', 71.75607811197793),
#  ('austen', '<s> yes yes i see you are </s>', 71.87271290874679),
#  ('austen', '<s> mrs elton was spoken of </s>', 71.90999747541744),
#  ('austen', '<s> he must love her </s>', 71.98213292932147),
#  ('austen', '<s> this will not do </s>', 72.03662712841333),
#  ('austen', '<s> i am sorry for that </s>', 72.21666673489928),
#  ('austen',
#   '<s> i am sure lady russell would like him </s>',
#   72.28618871156463),
#  ('austen',
#   '<s> she was so surprized she did not know what to do </s>',
#   72.34700705372329),
#  ('austen', '<s> they have no mercy on her </s>', 72.60728490245609),
#  ('austen',
#   '<s> i know it all i know it all cried mrs smith </s>',
#   72.74246483736755),
#  ('austen', '<s> this however was not the case </s>', 72.86523572978572),
#  ('melville', '<s> who can tell it </s>', 72.87393593553239),
#  ('austen',
#   '<s> i need not tell you what is to be done </s>',
#   73.08568015608759),
#  ('austen',
#   '<s> she wished him to speak but he would not </s>',
#   73.18468610320272),
#  ('austen',
#   '<s> she has been so kind as to promise it </s>',
#   73.23379043215503),
#  ('austen',
#   '<s> i have the highest opinion in the world of edward s heart </s>',
#   73.25448675793677),
#  ('carroll',
#   '<s> would you like to see a little of it </s>',
#   73.55261687777706),
#  ('austen', '<s> she has not the least idea </s>', 73.61514380548718),
#  ('austen', '<s> yes that of course </s>', 73.70848952569139),
#  ('austen', '<s> i will not say quite all </s>', 73.84734023746012),
#  ('austen',
#   '<s> she could never see a fault in any of them </s>',
#   73.85791275216353),
#  ('austen',
#   '<s> it was a gentleman it was colonel brandon himself </s>',
#   73.91934400890105),
#  ('austen',
#   '<s> i am afraid you must have had a shocking walk </s>',
#   73.99175325003372),
#  ('austen',
#   '<s> he had passed out of the room without a look </s>',
#   74.0269727323692),
#  ('austen', '<s> it was done however </s>', 74.13173775953378),
#  ('austen', '<s> he longed to see her </s>', 74.16690691578812),
#  ('austen', '<s> he is turning away </s>', 74.16913536032091),
#  ('austen',
#   '<s> she had nothing to say one day that she had not said the day before </s>',
#   74.49308973000122),
#  ('austen', '<s> they had mr elliot too </s>', 74.58267443403756),
#  ('austen',
#   '<s> you are not aware of what you are doing </s>',
#   74.60001064533168),
#  ('austen', '<s> it is like a woman s writing </s>', 74.68469540605385),
#  ('austen',
#   '<s> i am afraid ma am that it is not perfectly understood </s>',
#   74.8337187332091),
#  ('austen',
#   '<s> between mr frank churchill and miss fairfax </s>',
#   74.97480327885529),
#  ('austen',
#   '<s> you must be the best judge of your own happiness </s>',
#   75.20881318067757),
#  ('austen', '<s> i did not immediately recollect </s>', 75.23962765140868),
#  ('austen',
#   '<s> the appearance of the latter could not be more than the surprise of the moment </s>',
#   75.26629014867923),
#  ('austen',
#   '<s> she was most thankful for her own knowledge of him </s>',
#   75.30338582266752),
#  ('austen', '<s> i ought to travel </s>', 75.31325131302215),
#  ('austen', '<s> but you are always kind </s>', 75.31507207092255),
#  ('melville', '<s> how far off </s>', 75.32824023946237),
#  ('austen', '<s> to be sure i will if you wish it </s>', 75.38728382487494),
#  ('austen', '<s> i never met with her equal </s>', 75.59223358025793),
#  ('austen',
#   '<s> i am not in the least ashamed of my meaning </s>',
#   75.5944879341842),
#  ('austen',
#   '<s> mrs elton was very much disappointed </s>',
#   75.61453704979765),
#  ('austen', '<s> yes yes i understand you </s>', 75.6220780938307),
#  ('austen', '<s> i knew she would </s>', 75.6303581385483),
#  ('austen', '<s> you may esteem him </s>', 75.65175516275431),
#  ('austen',
#   '<s> yes and i shall be very happy in his acquaintance </s>',
#   75.90658631778423),
#  ('austen',
#   '<s> it must be a severe trial to them all </s>',
#   76.00532825907636),
#  ('austen',
#   '<s> i am sure william larkins will not like it </s>',
#   76.04325792127932),
#  ('austen', '<s> i could see it in his face </s>', 76.06518012079545),
#  ('austen', '<s> but do come in </s>', 76.14903547244816),
#  ('austen',
#   '<s> i am sure she will be married to mr willoughby very soon </s>',
#   76.17032094875303),
#  ('austen', '<s> she did not regret it </s>', 76.18999018541405),
#  ('carroll', '<s> i shall be late </s>', 76.19291905485856),
#  ('austen',
#   '<s> but mr knightley is so very fine a man </s>',
#   76.2823036919011),
#  ('austen',
#   '<s> you have been here only to be useful </s>',
#   76.30521143762336),
#  ('austen', '<s> my dear jane say no more about it </s>', 76.33307125135927),
#  ('carroll', '<s> but what am i to do </s>', 76.33409675102689),
#  ('austen', '<s> he does not care about jane fairfax </s>', 76.36711248157181),
#  ('austen',
#   '<s> i would not have mr knightley know any thing about it for the world </s>',
#   76.40791014527422),
#  ('austen',
#   '<s> but i assure you i have never been in the house above twice in my life </s>',
#   76.43546748437343),
#  ('austen', '<s> how do you like mrs </s>', 76.47706749341157),
#  ('austen',
#   '<s> i hope he will not mind it so very much </s>',
#   76.49804570570264),
#  ('austen', '<s> this is beyond every thing </s>', 76.77095831294052),
#  ('austen',
#   '<s> she had been used to affluence it was gone </s>',
#   76.83894711754678),
#  ('austen', '<s> when is it to take place </s>', 76.84628051244681),
#  ('austen',
#   '<s> if i could but play as well as you and miss fairfax </s>',
#   76.85163621668646),
#  ('austen', '<s> but take care of yourself </s>', 76.926494629503),
#  ('austen', '<s> you will like harriet </s>', 76.9946937415205),
#  ('austen', '<s> she was very fond of singing </s>', 77.28609282298144),
#  ('austen',
#   '<s> but as it is it must be out of anybody s power to assist him </s>',
#   77.29644041607114),
#  ('austen',
#   '<s> but there is nothing at all of that nature in the letter </s>',
#   77.4703942575908),
#  ('austen', '<s> i am concerned to hear of it </s>', 77.51976866400979),
#  ('austen', '<s> he walked by her side </s>', 77.58620936080685),
#  ('austen', '<s> i never want them i assure you </s>', 77.67642290654877),
#  ('austen',
#   '<s> you will see them both this morning i dare say </s>',
#   77.87612358451771),
#  ('austen', '<s> i knew he would </s>', 77.87887043138439),
#  ('austen', '<s> if you please my dear </s>', 78.1700667876982),
#  ('austen', '<s> they could think of no one else </s>', 78.26332615732764),
#  ('melville', '<s> tell me not of it </s>', 78.31812377700881),
#  ('austen',
#   '<s> there could be no doubt as to miss elliot </s>',
#   78.34110639279825),
#  ('austen', '<s> well so much the better for him </s>', 78.43876002979341),
#  ('austen', '<s> she cried well </s>', 78.5109088764279),
#  ('austen',
#   '<s> but however i hope you will think better of it </s>',
#   78.54750942167357),
#  ('austen', '<s> you must see the difference </s>', 78.82324293240053),
#  ('melville', '<s> i see no need of this </s>', 78.9841818962982),
#  ('austen', '<s> he does not read </s>', 79.03069547747641),
#  ('austen', '<s> yes i observed it i assure you </s>', 79.1080899577889),
#  ('austen', '<s> you will not be hysterical again </s>', 79.1161334583265),
#  ('austen', '<s> we shall not be many you know </s>', 79.26634770691636),
#  ('melville', '<s> but i do not mean anything sir </s>', 79.2867852599582),
#  ('austen',
#   '<s> we were always glad to see him at hartfield </s>',
#   79.28955899153344),
#  ('austen', '<s> do you know where they came from </s>', 79.51507485939429),
#  ('austen', '<s> how fond he was of it </s>', 79.55530320992887),
#  ('austen', '<s> he told her the news </s>', 79.63223582002483),
#  ('austen', '<s> shall i tell you </s>', 79.69816398653434),
#  ('austen', '<s> she had sought him </s>', 79.766766371143),
#  ('austen', '<s> but they always do you know </s>', 80.0369264796498),
#  ('austen',
#   '<s> i am sure you will like it of all things </s>',
#   80.09549542562803),
#  ('austen', '<s> yes do </s>', 80.1019324787212),
#  ('austen',
#   '<s> for mrs weston there was nothing to be done for harriet every thing </s>',
#   80.14418408569833),
#  ('melville', '<s> no he did not mean to at least </s>', 80.23714087140281),
#  ('austen', '<s> what would you advise me to do </s>', 80.2459551303458),
#  ('austen', '<s> you and i must part </s>', 80.30698261853348),
#  ('austen', '<s> what a disappointment it would be </s>', 80.3629530951442),
#  ('austen',
#   '<s> how it might be considered by the rest of the party she could not tell </s>',
#   80.36350453714607),
#  ('austen',
#   '<s> anne felt that she should like to know who he was </s>',
#   80.3690643286779),
#  ('austen', '<s> mr knightley is not she </s>', 80.53756108277764),
#  ('austen',
#   '<s> i am much obliged to you was her answer but i am not going with them </s>',
#   80.54551382700325),
#  ('austen', '<s> how do you do mr </s>', 80.5874003650327),
#  ('austen',
#   '<s> she would not have forgotten him so soon </s>',
#   80.66069440239123),
#  ('austen', '<s> it comes to the same thing </s>', 80.66184711417685),
#  ('melville', '<s> that s for us </s>', 80.68555498117071),
#  ('austen', '<s> she was certainly very civil to you </s>', 80.83459023057426),
#  ('austen', '<s> yes i understand the sort of mind </s>', 80.83687312243886),
#  ('austen', '<s> they will soon be in yorkshire </s>', 80.84184018061713),
#  ('austen',
#   '<s> it must be very clever or he would not have brought it </s>',
#   80.84457311525232),
#  ('austen', '<s> emma spoke for her </s>', 80.91873966256563),
#  ('austen', '<s> but you will do every thing right </s>', 80.93335499301983),
#  ('austen', '<s> said emma in a whisper </s>', 81.12751140351418),
#  ('austen',
#   '<s> what a pity it is that mr weston ever thought of her </s>',
#   81.31248448490166),
#  ('austen', '<s> his affection was all her own </s>', 81.3286840474653),
#  ('austen', '<s> i happened to be at lyme </s>', 81.35166404801214),
#  ('austen', '<s> i had none </s>', 81.38260275060763),
#  ('austen', '<s> my dear harriet what do you mean </s>', 81.43467084030944),
#  ('austen', '<s> well go on </s>', 81.54812476515144),
#  ('melville', '<s> but this did not last long </s>', 81.5623497216504),
#  ('austen', '<s> but who is he </s>', 81.60377180616041),
#  ('carroll', '<s> is that all </s>', 81.66588131833844),
#  ('austen', '<s> anne heard nothing of this </s>', 81.81911305213201),
#  ('austen', '<s> it is colonel brandon </s>', 81.85171917601953),
#  ('austen', '<s> why do you smile </s>', 81.92943664364148),
#  ('austen',
#   '<s> he had left the country in consequence </s>',
#   81.9891838525756),
#  ('austen', '<s> what did mr weston tell you </s>', 82.05620239894041),
#  ('austen',
#   '<s> i do not know any body who draws so well as you do </s>',
#   82.15785880122311),
#  ('austen',
#   '<s> yes i have no doubt of her being extremely attached to him </s>',
#   82.16151009149827),
#  ('austen', '<s> we thought you were to bring them </s>', 82.18625315667285),
#  ('austen', '<s> we shall never forget what you did </s>', 82.20133861627635),
#  ('melville', '<s> i knew no one in the place </s>', 82.21377079970917),
#  ('austen', '<s> you will know it all in time </s>', 82.31583337000271),
#  ('austen',
#   '<s> i shall not be far off if you want me </s>',
#   82.37819770271447),
#  ('austen',
#   '<s> how can you but the time will come i hope i am sure you will like him </s>',
#   82.55706239152572),
#  ('austen', '<s> but i shall see them tomorrow </s>', 82.56280344988758),
#  ('carroll',
#   '<s> i do wonder what can have happened to me </s>',
#   82.5934605786519),
#  ('austen', '<s> you know james benwick </s>', 82.70698129543808),
#  ('austen', '<s> she roused herself and went to him </s>', 82.76293971430559),
#  ('austen', '<s> i care for nothing else </s>', 82.76542187153738),
#  ('austen',
#   '<s> i am going home and you have an engagement with your friend </s>',
#   82.9513322800397),
#  ('austen',
#   '<s> i cannot believe that he has not the power of coming if he made a point of it </s>',
#   83.00536883796767),
#  ('austen',
#   '<s> i hope mrs bates and miss fairfax are </s>',
#   83.21142600994904),
#  ('austen', '<s> but i cannot believe it of you </s>', 83.21412443491984),
#  ('austen', '<s> if she has it now you have given it </s>', 83.2183634296778),
#  ('austen', '<s> that i can easily believe </s>', 83.22770217586435),
#  ('austen', '<s> very true said harriet </s>', 83.26718504665067),
#  ('austen', '<s> not go to town </s>', 83.34464956247692),
#  ('austen', '<s> she was quite in an agony </s>', 83.35575027486833),
#  ('austen',
#   '<s> i should like to know why you imagine i am </s>',
#   83.39015186324674),
#  ('austen', '<s> no it will not be worth while </s>', 83.43314498821995),
#  ('austen',
#   '<s> there was a little hesitation in emma s answer </s>',
#   83.45149851003252),
#  ('austen',
#   '<s> in half a minute they were in the room </s>',
#   83.4557861056582),
#  ('austen',
#   '<s> i am by no means assured of his regard for me </s>',
#   83.79891484386322),
#  ('austen', '<s> he staid an hour with them </s>', 83.91513464376555),
#  ('melville', '<s> i quaked to think of it </s>', 83.92132164844382),
#  ('austen',
#   '<s> i think you will like him said elinor when you know more of him </s>',
#   83.96540159610929),
#  ('austen',
#   '<s> i am sure i was very much surprized when i first heard she was going to be married </s>',
#   84.01246195498305),
#  ('austen', '<s> that must be enough for us both </s>', 84.01727323932106),
#  ('austen', '<s> it was at gibraltar mother i know </s>', 84.062450620495),
#  ('austen', '<s> but he told you that he loved you </s>', 84.13987033684732),
#  ('austen',
#   '<s> i do not know who would ever look at him in the company of the other </s>',
#   84.39294295416353),
#  ('austen', '<s> about jane fairfax </s>', 84.4056544469512),
#  ('austen', '<s> i am not at all afraid </s>', 84.48047163212146),
#  ('austen',
#   '<s> i am forgetting that i am not acquainted with her </s>',
#   84.51184119614281),
#  ('austen', '<s> you were perfectly right </s>', 84.5641945305161),
#  ('austen', '<s> it is a very simple story </s>', 84.588983763892),
#  ('austen', '<s> what is the gentleman s name </s>', 84.65104963783685),
#  ('melville', '<s> oh oh oh </s>', 84.7164231102157),
#  ('austen', '<s> it did torture me </s>', 84.8117282151197),
#  ('austen', '<s> such a home indeed </s>', 84.81955505690098),
#  ('melville', '<s> well well well </s>', 84.8909079132453),
#  ('austen', '<s> a very fine young man indeed </s>', 84.95226870574979),
#  ('austen', '<s> i would give any money for it </s>', 85.00008078816002),
#  ('austen', '<s> a great pity indeed </s>', 85.14297818736117),
#  ('austen',
#   '<s> captain benwick is very well i believe but he is a very odd young man </s>',
#   85.1702603322259),
#  ('austen',
#   '<s> he could not believe her to be encouraging him </s>',
#   85.27820084864534),
#  ('austen',
#   '<s> i am amazed that you should think of such a thing </s>',
#   85.32408044318088),
#  ('austen',
#   '<s> he must have a pretty good opinion of himself </s>',
#   85.36243777702217),
#  ('melville',
#   '<s> it is the easiest thing in the world for a man to look as if he had a great secret in him </s>',
#   85.37703721889523),
# ...
#  ('austen', '<s> i am c </s>', 94.46674110574394),
#  ('austen', '<s> how is she to day </s>', 94.5082226697176),
#  ('austen',
#   '<s> when i look back to the first time i saw him </s>',
#   94.62112293279985),
#  ('austen',
#   '<s> they will be much more able to give you something </s>',
#   94.62457040000352),
#  ('austen', '<s> that s right </s>', 94.67440895804714),
#  ('carroll', '<s> that s right </s>', 94.67440895804714),
#  ('austen', '<s> he held out his hand </s>', 94.7106513020774),
#  ('austen', '<s> elton jane fairfax and jane fairfax </s>', 94.73978739028867),
#  ('austen', '<s> i shall therefore set off to morrow </s>', 94.75284826563522),
#  ('melville', '<s> i am don </s>', 94.77330845166281),
#  ('austen',
#   '<s> in her own room she tried to comprehend it </s>',
#   94.77870407623831),
#  ('austen',
#   '<s> well i wish them happy with all my heart </s>',
#   94.86184338549239),
#  ('austen',
#   '<s> i do suspect that he is not really necessary to my happiness </s>',
#   94.99730752225031),
#  ('austen', '<s> it does not bear talking of </s>', 95.06518842310106),
#  ('austen',
#   '<s> it was something to feel that all the rest of my time might be given to hartfield </s>',
#   95.07205539106825),
#  ('austen', '<s> the ladies were all at home </s>', 95.13994234250767),
#  ('austen', '<s> i never saw such a likeness </s>', 95.1889305340753),
#  ('austen',
#   '<s> mrs weston laughed and said he did not know what he was talking about </s>',
#   95.23854727345497),
#  ('austen',
#   '<s> i am sure they were talking of me and i could not help thinking that he was persuading her to speak to me do you think he was miss woodhouse </s>',
#   95.26921816818182),
#  ('austen',
#   '<s> you have been no friend to harriet smith emma </s>',
#   95.27664236793055),
#  ('austen',
#   '<s> mr elton in very good spirits was one of the first to walk in </s>',
#   95.31960811658541),
#  ('austen',
#   '<s> but marianne in her place would not have done so little </s>',
#   95.43379621849773),
#  ('austen',
#   '<s> i do not know what you and mr willoughby will do between you about her </s>',
#   95.55859824658545),
#  ('austen', '<s> i shall not scold you </s>', 95.60470268710294),
#  ('austen',
#   '<s> you will not be sorry to find yourself at home </s>',
#   95.81534863083535),
#  ('melville', '<s> only one thing could be done </s>', 95.83944097382485),
#  ('austen',
#   '<s> but it is not to be imagined that she lives up to her income </s>',
#   95.85416999034649),
#  ('austen',
#   '<s> it would be the natural result of your affection for her </s>',
#   95.90924097121076),
#  ('austen', '<s> she would be a loser in every way </s>', 96.15734994029425),
#  ('melville', '<s> they have they have </s>', 96.22661490922926),
#  ('austen',
#   '<s> was mr ferrars in the carriage with her </s>',
#   96.3615685838577),
#  ('melville', '<s> i m quarried out of it </s>', 96.53829745056632),
#  ('austen', '<s> there had been the charm </s>', 96.56553802888095),
#  ('austen',
#   '<s> so obliged to you for the carriage last night </s>',
#   96.5800778018762),
#  ('austen', '<s> emma will be happy to entertain you </s>', 96.71467978068786),
#  ('austen', '<s> emma could not forgive her </s>', 96.72779068507789),
#  ('austen',
#   '<s> you do not go to town on horseback do you </s>',
#   96.95588241831516),
#  ('austen',
#   '<s> aye i believe that will be best for her </s>',
#   97.08445327270451),
#  ('austen',
#   '<s> he was not a great favourite with his fair sister in law </s>',
#   97.09077630198665),
#  ('carroll', '<s> who cares for you </s>', 97.15567630305509),
#  ('austen',
#   '<s> but i do assure you it was so for all that and i will tell you how it happened </s>',
#   97.1673929407816),
#  ('carroll',
#   '<s> i wonder if i shall ever see you any more </s>',
#   97.22474630387256),
#  ('melville', '<s> it was thus now </s>', 97.26865658376438),
#  ('austen',
#   '<s> and when is miss fairfax to leave you </s>',
#   97.29447945282773),
#  ('austen',
#   '<s> she had seen the same frederick wentworth </s>',
#   97.3817469829633),
#  ('austen', '<s> she saw him not far off </s>', 97.3864793407983),
#  ('austen',
#   '<s> she would be such a delightful companion for emma </s>',
#   97.46386831295324),
#  ('austen', '<s> do you think him so very plain </s>', 97.50740385878166),
#  ('austen', '<s> but sir john could not prevail </s>', 97.53789785132042),
#  ('austen',
#   '<s> he did not seem to want to be near enough for conversation </s>',
#   97.63595285547993),
#  ('austen', '<s> i have many things to support me </s>', 97.75601972049947),
#  ('austen', '<s> but i always thought i should </s>', 97.78698639714393),
#  ('austen', '<s> but what are you in doubt of </s>', 97.83277534275604),
#  ('austen',
#   '<s> but i thought he would have staid now and it would have been a pity not to have mentioned </s>',
#   97.9491532951816),
#  ('austen', '<s> i told you he was plain </s>', 98.1614187116995),
#  ('austen',
#   '<s> do you mean with regard to this letter </s>',
#   98.1895728383908),
#  ('austen',
#   '<s> and you must be off this very morning </s>',
#   98.21077081065053),
#  ('austen', '<s> i must order the carriage </s>', 98.24859433084463),
#  ('austen', '<s> that is exactly what i said my dear </s>', 98.300419312331),
#  ('austen',
#   '<s> i want you to talk about me to mr elliot </s>',
#   98.38751119047095),
#  ('austen', '<s> and elizabeth too </s>', 98.3971654400482),
#  ('carroll', '<s> how can i have done that </s>', 98.40953785425025),
#  ('austen',
#   '<s> if you were to see what a headache she has </s>',
#   98.45117595244959),
#  ('austen', '<s> what is it my dear friend </s>', 98.47722834386745),
#  ('austen',
#   '<s> though i think he had better not have married </s>',
#   98.48243037577525),
#  ('austen', '<s> the past was nothing </s>', 98.58029070321189),
#  ('austen',
#   '<s> mrs dashwood smiled and said nothing </s>',
#   98.77924433951732),
#  ('austen',
#   '<s> my dear emma i have told you what led me to think of it </s>',
#   98.80576460898584),
#  ('austen',
#   '<s> yes it is about miss williams i am sure </s>',
#   98.88788236267524),
#  ('austen', '<s> don t you mr </s>', 98.99497667501016),
#  ('carroll', '<s> i wish you were down here with me </s>', 98.99656454838103),
#  ('melville', '<s> something must have happened </s>', 99.08337195567286),
#  ('austen', '<s> she made no reply </s>', 99.11009583565404),
#  ('austen',
#   '<s> i have been told that you were asked to be of the party </s>',
#   99.15243090034562),
#  ('austen', '<s> i think lady russell would like him </s>', 99.1723786628264),
#  ('austen',
#   '<s> it was now about the time that she was likely to call </s>',
#   99.18224391739075),
#  ('austen',
#   '<s> i will tell you why she is out of spirits </s>',
#   99.21826823544826),
#  ('austen',
#   '<s> and that you are very likely to do very soon i can tell you ma am said charles </s>',
#   99.27036350276583),
#  ('austen', '<s> not know mr elliot indeed </s>', 99.30505587324424),
#  ('austen', '<s> i knew how soon he would come </s>', 99.37688841844756),
#  ('austen', '<s> i shall have done in five minutes </s>', 99.52922342381784),
#  ('austen',
#   '<s> i hope he will be more agreeable now </s>',
#   99.54143645301595),
#  ('austen', '<s> leave it to me </s>', 99.58312817423614),
#  ('austen', '<s> you must not talk so marianne </s>', 99.80949726991535),
#  ('austen', '<s> it is certainly very well regulated </s>', 99.94653531120153),
#  ('austen', '<s> i wonder what will become of her </s>', 99.96320771628234),
#  ('austen', '<s> i am always well you know </s>', 99.9941091895642),
#  ('austen',
#   '<s> i am very glad you did and that you communicated it to me </s>',
#   100.03311020673523),
#  ('austen', '<s> mr palmer is so droll </s>', 100.12990120122275),
#  ('austen', '<s> you can have no grief </s>', 100.15352931896096),
#  ('austen',
#   '<s> that was a great deal too smart for me </s>',
#   100.17597490262214),
#  ('austen', '<s> it was ten o clock </s>', 100.21878962622158),
#  ('austen',
#   '<s> we have notice of it in a letter to day </s>',
#   100.2351226120833),
#  ('austen',
#   '<s> it is the garden of england you know </s>',
#   100.27233485269325),
#  ('austen', '<s> i shall sit by you </s>', 100.28970353608972),
#  ('carroll',
#   '<s> that will be a queer thing to be sure </s>',
#   100.35689731343071),
#  ('austen', '<s> they were all at her disposal </s>', 100.40474381044294),
#  ('austen', '<s> how d ye do </s>', 100.42708940584184),
#  ('austen', '<s> can this be possible </s>', 100.47722891637747),
#  ('austen',
#   '<s> it will be giving him so much pleasure </s>',
#   100.53134520206504),
#  ('austen',
#   '<s> do you know that you are quite rude </s>',
#   100.55034498377498),
#  ('austen', '<s> what can you possibly have to do </s>', 100.58544123791994),
#  ('austen', '<s> oh don t think of me </s>', 100.60129900692708),
#  ('austen',
#   '<s> and upon my word i do not think mr knightley would be much disturbed by miss bates </s>',
#   100.63361288058282),
#  ('austen',
#   '<s> mr weston certainly would never marry again </s>',
#   100.70435257978731),
#  ('austen', '<s> he is no hypocrite now </s>', 100.86508449872083),
#  ('melville', '<s> no sir i never have </s>', 100.93084954200503),
#  ('austen', '<s> i am so ill i can hardly speak </s>', 100.93560030112864),
#  ('austen', '<s> ay to be sure i thought as much </s>', 100.94327829794254),
#  ('austen',
#   '<s> i did not think charles would have been so unfeeling </s>',
#   100.94746185497515),
#  ('austen',
#   '<s> i had a letter from him this morning and he will be with us within a fortnight </s>',
#   100.98670322860306),
#  ('austen',
#   '<s> she is very fond of frank and therefore i would not speak ill of her </s>',
#   100.98769241640504),
#  ('carroll',
#   '<s> i think i may as well go in at once </s>',
#   100.99325089584497),
#  ('austen', '<s> she was a widow and poor </s>', 101.14064911106396),
#  ('austen', '<s> there is not much difference </s>', 101.15865398402403),
#  ('austen', '<s> elinor attempted no more </s>', 101.18870194315541),
#  ('melville', '<s> i am mistaken then </s>', 101.2308477791814),
#  ('carroll', '<s> it all came different </s>', 101.2435545157684),
#  ('austen',
#   '<s> she only attempted to say how do you do </s>',
#   101.25058217469584),
#  ('austen',
#   '<s> nothing could have done it away to my feelings </s>',
#   101.32323874866573),
#  ('austen', '<s> mrs weston was disappointed </s>', 101.39522531273563),
#  ('austen',
#   '<s> he is a man said lady russell whom i have no wish to see </s>',
#   101.63864942252485),
#  ('austen',
#   '<s> no indeed there was not a hint of mr martin </s>',
#   101.65014382706083),
#  ('carroll',
#   '<s> there was certainly too much of it in the air </s>',
#   101.72435812899583),
#  ('carroll', '<s> what sort of a dance is it </s>', 101.8295018107897),
#  ('austen', '<s> i see how it is said she </s>', 101.87683785034471),
#  ('austen',
#   '<s> captain wentworth must be out of sight </s>',
#   101.90801553716942),
#  ('austen', '<s> i shall certainly be at leisure </s>', 101.97093020615188),
#  ('austen',
#   '<s> be sure to give me intelligence of the letter as soon as possible </s>',
#   102.06759661212189),
#  ('austen',
#   '<s> i have a very strong notion that it comes from him </s>',
#   102.23672837100466),
#  ('austen', '<s> i do not see much sign of it </s>', 102.29667500944146),
#  ('melville', '<s> so it is so it is if we get it </s>', 102.35151067768689),
#  ('austen', '<s> yes perhaps it had been mr elliot </s>', 102.3639002565742),
#  ('austen',
#   '<s> i will leave you said elinor if you will go to bed </s>',
#   102.64598757195888),
#  ('austen',
#   '<s> i assure you i have no doubt of its doing mr woodhouse good </s>',
#   102.6485537568064),
#  ('austen',
#   '<s> it is so much beyond any thing i deserve </s>',
#   102.65108193323879),
#  ('austen',
#   '<s> i would give anything to know the truth of it </s>',
#   102.65813456093962),
#  ('melville', '<s> may be may be </s>', 102.74175142795352),
#  ('austen', '<s> poor old gentleman </s>', 102.80466579839049),
#  ('austen', '<s> my mother s spectacles </s>', 102.89723366319969),
#  ('austen', '<s> thank you dear miss woodhouse </s>', 102.92070162496522),
#  ('austen',
#   '<s> i am sure she will be as happy to see her friends at highbury as they can be to see her </s>',
#   102.9804256023478),
#  ('austen', '<s> he was generally thought so </s>', 103.0820754677672),
#  ('austen', '<s> gone to mr woodhouse s </s>', 103.15701642285977),
#  ('austen',
#   '<s> he had not the power of accepting it </s>',
#   103.16427565507092),
#  ('austen',
#   '<s> a few days had made a change indeed </s>',
#   103.16516104596955),
#  ('austen', '<s> not at all sir </s>', 103.1742751678198),
#  ('austen', '<s> but they should meet again </s>', 103.17510654391013),
#  ('austen',
#   '<s> i thank you but i assure you you are quite mistaken </s>',
#   103.33413140430933),
#  ('austen', '<s> should not you mr </s>', 103.38058705243614),
#  ('austen',
#   '<s> but ever since we had the history of that day i have been so fond of mr </s>',
#   103.48818751793189),
#  ('austen', '<s> what is the amount of his fortune </s>', 103.54275877864409),
#  ('austen',
#   '<s> his mother and sisters were very fond of him </s>',
#   103.54413218966467),
#  ('austen',
#   '<s> and i believe marianne will be the most happy with him of the two </s>',
#   103.58161258838706),
#  ('austen',
#   '<s> i shall not give you any advice harriet </s>',
#   103.6451254322395),
#  ('austen', '<s> how sorry i am </s>', 103.67670836353605),
#  ('austen',
#   '<s> i suppose you know ma am that mr ferrars is married </s>',
#   103.68532937290051),
#  ('austen',
#   '<s> you do us a great deal of honour to day i am sure </s>',
#   103.69673687208011),
#  ('austen',
#   '<s> it would be an excellent match for he was rich and she was handsome </s>',
#   103.76664096077639),
#  ('austen', '<s> she recovered her voice </s>', 103.79579944449577),
#  ('carroll', '<s> one indeed </s>', 103.87253451237869),
#  ('austen', '<s> he is always out of humour </s>', 103.88160625453536),
#  ('austen', '<s> it was her superior duty </s>', 103.88592481604387),
#  ('austen',
#   '<s> she was persuaded by lady russell s countenance that she had seen him </s>',
#   104.00917217973782),
#  ('carroll', '<s> i dare say there may be one </s>', 104.02951409888605),
#  ('austen',
#   '<s> i have not the smallest doubt of the issue </s>',
#   104.04812406586056),
#  ('austen',
#   '<s> i am only afraid of your sitting up for me </s>',
#   104.08360669033691),
#  ('austen',
#   '<s> there can be no doubt of its being written for you and to you </s>',
#   104.23025539331258),
#  ('austen', '<s> but soon it came to be on one side </s>', 104.33834761790983),
#  ('austen',
#   '<s> you have been long acquainted with colonel brandon have not you </s>',
#   104.44589498149719),
#  ('austen', '<s> leave it all to me </s>', 104.54661391601581),
#  ('austen',
#   '<s> i was once very near and i wish i had it would have been better </s>',
#   104.55274160182799),
#  ('austen',
#   '<s> there is no comparison between them </s>',
#   104.63579559591705),
#  ('austen',
#   '<s> how mortifying to feel that it was so </s>',
#   104.66845647287302),
#  ('austen',
#   '<s> i dare say there was a difference when i was staying with them the other day </s>',
#   104.67882879782385),
#  ('austen', '<s> he cried you would </s>', 104.71133165189472),
#  ('austen',
#   '<s> it is so delightful that you should live at the cottage </s>',
#   104.76746758651677),
#  ('austen',
#   '<s> as soon as i am cooler i shall go back again </s>',
#   104.79818934383253),
#  ('austen',
#   '<s> you will allow me to bring jane fairfax </s>',
#   104.85839153389779),
#  ('austen',
#   '<s> she had no doubt of what mr weston was often thinking about </s>',
#   104.89512157997052),
#  ('austen',
#   '<s> it is to be a secret i conclude said he </s>',
#   104.93357229237095),
#  ('austen',
#   '<s> i am sure i must have been as white as my gown </s>',
#   105.00824375972334),
#  ('austen',
#   '<s> i want to have your opinion of her looks </s>',
#   105.0748691443244),
#  ('austen',
#   '<s> he will be able to tell her how we all are </s>',
#   105.08557710780481),
#  ('austen',
#   '<s> that is what i like that is what a young man ought to be </s>',
#   105.10238194214116),
#  ('austen',
#   '<s> if colonel campbell is not the person who can be </s>',
#   105.12306795497337),
#  ('austen', '<s> she shewed it to me </s>', 105.13027041493066),
#  ...]

# %% [markdown]
# # iterate
#
# this is meant to be an iterative algorithm, so we add the top sentences (using threshold) to the original training data, make a new language model, and calculate new perplexity scores over the outside data.

# %%
iters = 500

add_corpus = corpus[:]       # the expanding id-corpus
rem_unlabeled = unlabeled[:] # the shrinking unlabeled data
additions = []               # track additions to lm corpus
threshhold = 100.0           # perplexity threshhold
cutoff = 25                  # cutoff for added sents, make large to 'ignore'
k = 0.001                    # smoothing term for perplexity add-k smoothing

for i in range(iters):
    
    # EarlyStopping
    cnt = 0
    
    # indices to remove from unlabeled data
    remove_idx = []
    
    # build language model
    vocabsize, vocab_counts, bigram_counts = languagemodel(add_corpus)
    
    # rank perplexities
    perplexities = [perplexity(s[1], k) for s in rem_unlabeled]
    
    # take top sents
    add = 0
    for idx, perp in enumerate(perplexities):
        if perp < threshhold:
            additions.append(rem_unlabeled[idx])
            add_corpus.append(rem_unlabeled[idx][1])
            remove_idx.append(idx)
            cnt += 1
            add += 1
        if add == cutoff:
            break
    
    # filter out additions
    rem_unlabeled = [rem_unlabeled[i] for i in range(len(rem_unlabeled)) if i not in remove_idx]
    
    # if no added sents, terminate
    if cnt == 0:
        print("no added sentences, stopping...\n")
        debug = [(x[0], ' '.join(x[1]), y) for x, y in sorted(zip(rem_unlabeled, perplexities), key=lambda pair: pair[1])][:100]
        for d in debug[:10]:
            print(d)
        break
    
    if i > 0 and i % 10 == 0:
        print("iter", i, ": total added", len(additions), "sents")
# Out:
# iter 10 : total added 275 sents
# iter 20 : total added 525 sents
# iter 30 : total added 775 sents
# iter 40 : total added 1025 sents
# iter 50 : total added 1275 sents
# iter 60 : total added 1525 sents
# iter 70 : total added 1775 sents
# iter 80 : total added 2025 sents
# no added sentences, stopping...
#
# ('austen', '<s> i will bring friends with me </s>', 100.12580280007327)
# ('melville', '<s> i ll smoke no more </s>', 100.38171885922225)
# ('austen', '<s> have you any idea of mr knightley s returning your affection </s>', 100.47742319488515)
# ('austen', '<s> i beg your pardon mr dashwood but if he had done otherwise i should have thought him a rascal </s>', 100.78898086385561)
# ('austen', '<s> you are not striving to look taller than any body else </s>', 100.84412001883004)
# ('austen', '<s> i hope i know better now than to care for mr martin or to be suspected of it </s>', 100.89671134869269)
# ('austen', '<s> well i wish him out of all his trouble with all my heart and a good wife into the bargain </s>', 100.90137481658695)
# ('austen', '<s> that was your doing papa </s>', 101.07421023644127)
# ('austen', '<s> it was the only intelligible motive </s>', 101.3565659650638)
# ('melville', '<s> the boy s hand on the hill </s>', 101.38193705029596)

# %% [markdown]
# ## evaluation

# %%
diff = len(add_corpus) - len(corpus)
totl = len(unlabeled)
print("sents found:", diff, "(%", diff*100/totl, "of unlabeled)")
# Out:
# sents found: 2189 (% 9.970393987702119 of unlabeled)

# %%
labels = [t[0] for t in additions]
corrects = [t[0] for t in additions if t[0]=='austen']
print("precision of found sents: ", len(corrects)/len(labels))
# Out:
# precision of found sents:  0.8990406578346277

# %%
recall = len(corrects)/len(withheld)
print("recall of unlabeled austen sents: ", recall)
# Out:
# recall of unlabeled austen sents:  0.16988950276243095
