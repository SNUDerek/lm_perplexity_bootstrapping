# %% [markdown]
# # corpus bootstrapping with LM perplexity
#
# toy test of Ramaswamy, Printz, Gopalakrishnan: *A Bootstrap Technique for Building Domain-Dependent Langauge Models*
# http://mirlab.org/conference_papers/International_Conference/ICSLP%201998/PDF/SCAN/SL980611.PDF
#
# - uses simple bigram LM with add-k smoothing
# - in-domain data from Jane Austen
# - 'unlabeled' corpus of Austen,Carroll and Melville sentences

# %%
from collections import Counter
import math
import nltk
import random
import re

# %% [markdown]
# # in-domain corpus data
#
# load the three jane austen texts as tokenized sentences, preprocess (lowercase, remove punctuation etc, add `<s>` and `</s>` tags)

# %%
# read corpora
austen1 = nltk.corpus.gutenberg.sents('austen-emma.txt')
austen2 = nltk.corpus.gutenberg.sents('austen-persuasion.txt')
austen3 = nltk.corpus.gutenberg.sents('austen-sense.txt')
data = austen1 + austen2 + austen3
print(len(data))
# Out:
# 16498

# %%
# %%time
# shuffle data and withhold random set
indices = [i for i in range(len(data))]
random.shuffle(indices)
data = [data[i] for i in indices]

test_idx = int(len(data)*0.25)
corpus = data[:test_idx]
withheld = data[test_idx:]
data = None # clear
print(len(corpus), len(withheld))
# Out:
# 4124 12374
# CPU times: user 5.88 s, sys: 92 ms, total: 5.97 s
# Wall time: 5.97 s

# %% [markdown]
# ## preprocessing
#
# remove sents of len < 5 (words)

# %%
# %%time
# preprocess data (with function)
def preprocess(tokens):
    processed = []
    for sent in tokens:
        if len(sent) > 4:
            this_sent = []
            for word in sent:
                if re.findall(r'[0-9A-Za-z]+', word):
                    this_sent.append(word.lower())
            this_sent = ['<s>'] + this_sent + ['</s>']
            processed.append(this_sent)
    return processed
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 3.58 µs

# %%
corpus = preprocess(corpus)
withheld = preprocess(withheld)
print("seed corpus:", len(corpus), "withheld:", len(withheld))
# Out:
# seed corpus: 3858 withheld: 11600

# %% [markdown]
# # build bigram language model
#
# we will constuct this as a function so we can iterate

# %%
def languagemodel(corpus):
    
    # bigramize and get vocabulary
    bigrams = []
    vocab = []
    for sent in corpus:
        # split
        for i in range(len(sent)-1):
            vocab.append(sent[i])
            bigrams.append((sent[i], sent[i+1]))
        vocab.append(sent[-1])
        
    # get vocabulary size, counters
    # oovs will be handled by smoothing
    vocabsize = len(set(vocab))
    vocab_counts = Counter(vocab)
    bigram_counts = Counter(bigrams)
    
    return vocabsize, vocab_counts, bigram_counts

# %%
# %%time
vocabsize, vocab_counts, bigram_counts = languagemodel(corpus)
# Out:
# CPU times: user 68 ms, sys: 12 ms, total: 80 ms
# Wall time: 78.8 ms

# %% [markdown]
# # perplexity measurement
#
# this is a function of the probability of a given sentence under this language model's assumptions (i.e the product of the probability of each bigram normalized by the total sentence length)
#
# we use add-k smoothing to account for out-of-vocab terms

# %%
# perplexity calculation with add-k smoothing
# from http://www3.cs.stonybrook.edu/~has/CSE594/Notes/(1)%20Probability%20Theory%20Application%201-28.pdf
def perplexity(sent, k=0.1):
    # tokenize and bigramize
    bigrams = []
    for i in range(len(sent)-1):
        bigrams.append((sent[i], sent[i+1]))
        
    # for each bigram, get probability (add-one smoothed)
    # p(w_i | w_i-1) = count(w_i-1, w_i) + 1 / count(w_i-1 + N)
    probs = []
    for bigram in bigrams:
        b_c = bigram_counts[bigram] + k
        w_c = vocab_counts[bigram[0]] + k*vocabsize
        probs.append(b_c/w_c)
    
    # get inverse
    inverse = [1.0/prob for prob in probs]
    
    # get product
    product = 1.0
    for inv in inverse:
        product *= inv
    
    # n-th root
    perplexity = math.pow(product, (1/len(sent)))
    
    return perplexity

# %% [markdown]
# # external corpus
#
# this is data from an external source that (hopefully) includes some sentences that we can use for data augmentation.
#
# here we (artificially) create a mixed id/ood corpus by mixing our withheld data in with some text from another source. we will use moby dick because it is one of the NLTK prose texts closer in time to Jane Austen
#
# for testing, we will label each sentence according to source

# %%
withheld = [('austen', s) for s in withheld]
len(withheld)
# Out:
# 11600

# %%
melville = nltk.corpus.gutenberg.sents('melville-moby_dick.txt')
melville = preprocess(melville)
melville = [('melville', s) for s in melville]

carroll = nltk.corpus.gutenberg.sents('carroll-alice.txt')
carroll = preprocess(carroll)
carroll = [('carroll', s) for s in carroll]

len(melville), len(carroll)
# Out:
# (8857, 1514)

# %%
unlabeled = withheld + melville + carroll
len(unlabeled)
# Out:
# 21971

# %% [markdown]
# # sort by perplexity score
#
# as we can see, in-domain answers are at the top. of course it is not the case that necessarily all *(true)* in-domain sentences are at the top of the list.

# %%
# %%time
# get perplexities
perplexities = [perplexity(s[1]) for s in unlabeled]
# Out:
# CPU times: user 448 ms, sys: 0 ns, total: 448 ms
# Wall time: 445 ms

# %%
# sort by perplexity (lower = better)
[(x[0], ' '.join(x[1]), y) for x, y in sorted(zip(unlabeled, perplexities), key=lambda pair: pair[1])]
# Out:
# [('austen', '<s> i do not know </s>', 14.729173304674147),
#  ('austen', '<s> i do not know </s>', 14.729173304674147),
#  ('austen', '<s> i do not know </s>', 14.729173304674147),
#  ('austen', '<s> i am sure i do not know </s>', 16.39012305889204),
#  ('carroll', '<s> i had not </s>', 17.045270817412888),
#  ('austen', '<s> she had seen him </s>', 18.171172050776057),
#  ('austen', '<s> i am sure i had not </s>', 18.19799968118952),
#  ('melville', '<s> i am sure that i did not </s>', 19.704061956263423),
#  ('austen', '<s> i do not see it </s>', 19.839176305286784),
#  ('austen', '<s> i think it is so </s>', 20.05698120009778),
#  ('austen', '<s> i am very happy </s>', 20.77234144496522),
#  ('austen', '<s> i am sure you will not like him </s>', 20.95163418579466),
#  ('melville', '<s> i will tell you </s>', 21.454686379053655),
#  ('austen', '<s> yes i do </s>', 22.640216351337635),
#  ('melville', '<s> but it is not so </s>', 22.66385587291757),
#  ('austen', '<s> i am said he </s>', 22.958280323796355),
#  ('austen', '<s> to be sure </s>', 23.148259245945635),
#  ('austen', '<s> it is very true </s>', 23.755458959065347),
#  ('melville', '<s> i do as i do </s>', 23.87138501014406),
#  ('austen', '<s> i am sorry for it </s>', 23.899004420056468),
#  ('austen', '<s> i do not know my dear </s>', 24.313576460279613),
#  ('austen', '<s> i am glad of it </s>', 24.404028087336616),
#  ('austen', '<s> to be sure i am </s>', 24.45604523323222),
#  ('austen', '<s> you will not see him </s>', 24.801709922795386),
#  ('austen', '<s> i do not think they were </s>', 25.04828048636381),
#  ('austen', '<s> you are very good </s>', 25.165413289121407),
#  ('austen', '<s> i am sure i do not know who is not </s>', 26.346262730615543),
#  ('austen', '<s> i thought it must be so </s>', 27.215723612337253),
#  ('austen', '<s> she could not stay </s>', 27.267270616188565),
#  ('austen', '<s> i am so glad to see you </s>', 27.509288025865875),
#  ('austen', '<s> my dear miss dashwood </s>', 27.685483303483476),
#  ('austen', '<s> i am sick of it </s>', 27.747339138672515),
#  ('austen', '<s> i did not know what to do </s>', 27.81372772973668),
#  ('austen', '<s> i am sure you will agree with me </s>', 27.815840827522074),
#  ('austen', '<s> i know he did </s>', 28.01855658788649),
#  ('melville', '<s> i would not take it </s>', 28.05157748374692),
#  ('austen', '<s> not at all </s>', 28.203065367990224),
#  ('austen', '<s> not at all </s>', 28.203065367990224),
#  ('austen', '<s> not at all </s>', 28.203065367990224),
#  ('austen', '<s> i am sure she does </s>', 28.74637915656068),
#  ('austen', '<s> she would indeed </s>', 28.93922601060563),
#  ('austen', '<s> it was not so very bad </s>', 28.95247946888033),
#  ('austen', '<s> my dear mrs </s>', 29.010129494737804),
#  ('austen', '<s> i have had such a time of it </s>', 29.18010214502675),
#  ('austen', '<s> it is over </s>', 29.43208943356256),
#  ('melville', '<s> you must have heard of it </s>', 29.630960105543),
#  ('austen', '<s> i assure you i have </s>', 29.947693750525683),
#  ('austen', '<s> you are very kind </s>', 30.062096550082252),
#  ('austen', '<s> he would be so very </s>', 30.136994544484708),
#  ('austen', '<s> cried mr knightley </s>', 30.421166916543914),
#  ('austen', '<s> i do not know what he would be at </s>', 30.432512390018413),
#  ('melville', '<s> i thought so </s>', 31.08138934472587),
#  ('austen', '<s> what do you think of him </s>', 31.286171546398666),
#  ('austen', '<s> i am extremely happy </s>', 31.348033221276005),
#  ('austen', '<s> i could not have believed it </s>', 31.437257462828452),
#  ('melville', '<s> but this is not all </s>', 31.661875469679707),
#  ('melville', '<s> but this is not all </s>', 31.661875469679707),
#  ('austen',
#   '<s> i was very much pleased with all that he said </s>',
#   31.86371077903937),
#  ('austen', '<s> but it was too late </s>', 32.00530316301824),
#  ('austen', '<s> mr martin </s>', 32.11565023100025),
#  ('austen', '<s> i have done very little </s>', 32.21398321824209),
#  ('austen', '<s> she could not speak </s>', 32.526432477758384),
#  ('austen', '<s> that i am sure you would </s>', 32.534835398271134),
#  ('austen', '<s> my dear miss elliot </s>', 32.690436854235834),
#  ('austen', '<s> you will excuse me </s>', 32.91997571913657),
#  ('austen', '<s> i am going home </s>', 32.966072935393086),
#  ('austen', '<s> as to that i do not </s>', 33.19413106603752),
#  ('austen', '<s> said mr weston </s>', 33.225591628129465),
#  ('austen', '<s> i knew how it would be </s>', 33.37284549178055),
#  ('austen',
#   '<s> they will be so very happy to see you </s>',
#   33.77970615015913),
#  ('austen', '<s> as a friend </s>', 34.07421231985571),
#  ('austen', '<s> what was to be done </s>', 34.11370154956173),
#  ('austen',
#   '<s> i am sure you must have heard of her before </s>',
#   34.20078872682445),
#  ('austen', '<s> i have no patience with him </s>', 34.42835298107356),
#  ('austen', '<s> to be sure he is </s>', 34.44364847161659),
#  ('austen', '<s> you are very much mistaken </s>', 34.53175299391892),
#  ('austen', '<s> well miss woodhouse </s>', 34.92790841195933),
#  ('austen', '<s> he had no idea of me </s>', 35.1093833778796),
#  ('austen', '<s> this was too much </s>', 35.28587086766158),
#  ('austen', '<s> nothing at all </s>', 35.405474553561575),
#  ('austen', '<s> she was not sorry </s>', 35.49594769584937),
#  ('austen', '<s> i like them all </s>', 35.65069858295983),
#  ('austen', '<s> you know what you are about </s>', 35.814844567563476),
#  ('austen', '<s> i do not pretend to it </s>', 35.826774098135836),
#  ('austen', '<s> she hoped it was not so </s>', 35.98233162702251),
#  ('austen', '<s> i am always glad to see him </s>', 36.094828429545075),
#  ('carroll', '<s> what is it </s>', 36.13054440389093),
#  ('austen', '<s> mr knightley and jane fairfax </s>', 36.14495696503655),
#  ('austen', '<s> to be sure it will </s>', 36.3595088783118),
#  ('austen', '<s> that i had never seen her </s>', 36.531660894501755),
#  ('austen', '<s> to be sure you did </s>', 36.68418984794076),
#  ('austen', '<s> you are right </s>', 36.72007414692387),
#  ('austen',
#   '<s> you must have heard every thing to be sure </s>',
#   37.24547226601703),
#  ('austen', '<s> i assure you i shall not </s>', 37.65428526274519),
#  ('austen', '<s> she did not regret it </s>', 37.8623996572189),
#  ('austen',
#   '<s> i am sure he has not the least idea of it </s>',
#   38.05772512533666),
#  ('austen', '<s> yes he had done it </s>', 38.525437620772706),
#  ('austen', '<s> no indeed it is not </s>', 38.529821085624924),
#  ('austen', '<s> it was a commission to me </s>', 38.68592837349722),
#  ('austen', '<s> i know it has </s>', 38.737624315486975),
#  ('austen', '<s> mr elliot was in bath </s>', 39.02340644189281),
#  ('austen', '<s> no indeed i am not </s>', 39.229797746114485),
#  ('austen',
#   '<s> i am sure she will be pleased with the children </s>',
#   39.27157257721523),
#  ('austen', '<s> he had been going to call on them </s>', 39.33254732073102),
#  ('melville', '<s> it was the while </s>', 39.53544667973321),
#  ('austen', '<s> i hope she is well </s>', 39.98051774422867),
#  ('austen', '<s> she wanted to be alone </s>', 40.04093404569136),
#  ('austen', '<s> i know him well </s>', 40.21850261757229),
#  ('austen', '<s> i shall never forget it </s>', 40.57669699941959),
#  ('austen', '<s> i assure you she did </s>', 40.705964347534234),
#  ('austen', '<s> i never heard of such a thing </s>', 40.80055169795189),
#  ('austen',
#   '<s> i am glad i did not think of it before </s>',
#   40.92937121339008),
#  ('melville', '<s> and so it was </s>', 41.21262865020498),
#  ('austen', '<s> but miss bates and miss fairfax </s>', 41.30871220946169),
#  ('austen', '<s> do you i have no doubt </s>', 41.71711757091137),
#  ('austen', '<s> it was his duty </s>', 41.99818195244824),
#  ('austen', '<s> her father and harriet </s>', 42.00554736696786),
#  ('austen', '<s> it was no more than a wish </s>', 42.124021994723314),
#  ('austen', '<s> so very kind </s>', 42.17992467283724),
#  ('austen', '<s> do you think it is a good one </s>', 42.36795889667681),
#  ('austen', '<s> to be sure it would </s>', 42.43292069227052),
#  ('austen', '<s> i am monstrous glad of it </s>', 42.45650050526989),
#  ('austen', '<s> and i am sure sir </s>', 42.58791541451608),
#  ('austen', '<s> i see you know nothing of the matter </s>', 42.7061714971423),
#  ('austen', '<s> she had a great wish to see him </s>', 42.76666267535453),
#  ('austen', '<s> no more it is </s>', 42.8722786295712),
#  ('austen', '<s> emma could not doubt </s>', 43.10680049664243),
#  ('austen', '<s> and it was soon over </s>', 43.17338464638191),
#  ('austen', '<s> the best of all </s>', 43.18269186394176),
#  ('austen', '<s> you are very wrong </s>', 43.2687597840592),
#  ('melville', '<s> what do you think </s>', 43.59156891152586),
#  ('austen', '<s> how can you think of such a thing </s>', 43.62275715191753),
#  ('austen', '<s> i am very angry with you </s>', 43.864514346230344),
#  ('austen', '<s> i am sure we do </s>', 43.93101699560481),
#  ('melville', '<s> and what is it </s>', 44.18644323032797),
#  ('austen', '<s> she was perfectly convinced of it </s>', 44.30858523082382),
#  ('austen', '<s> i could not answer it </s>', 44.357970867466435),
#  ('melville', '<s> yes but i should like to see him </s>', 44.36025107096505),
#  ('austen', '<s> i hope she does </s>', 44.36396658989126),
#  ('austen', '<s> i should wish it </s>', 44.37539223707169),
#  ('austen', '<s> i have thought only of you </s>', 44.52566851607473),
#  ('austen', '<s> there it is </s>', 44.5586718398934),
#  ('austen', '<s> she never did you know </s>', 44.66508094388385),
#  ('melville', '<s> i want to see the world </s>', 44.79693198492864),
#  ('austen', '<s> you are very obliging </s>', 45.12682345192944),
#  ('austen', '<s> i am perfectly satisfied of both </s>', 45.14298423287163),
#  ('austen', '<s> and to what part of it </s>', 45.16122681923829),
#  ('austen', '<s> very well i am much obliged to you </s>', 45.17483424592772),
#  ('melville', '<s> there you have him </s>', 45.19650187429813),
#  ('austen', '<s> i like him very well </s>', 45.44856186032782),
#  ('austen',
#   '<s> i have no doubt of his being a very respectable young man </s>',
#   45.47647262592201),
#  ('austen', '<s> i know we shall be happy </s>', 45.73125278696012),
#  ('austen', '<s> i do not dislike him </s>', 45.85386517559767),
#  ('austen', '<s> do you think so </s>', 45.91341428555971),
#  ('austen', '<s> i do not care for myself </s>', 45.99961924647706),
#  ('austen',
#   '<s> i am sure she is very good i hope she will be very happy </s>',
#   46.01140099278153),
#  ('austen', '<s> she could say nothing </s>', 46.546710243824315),
#  ('austen', '<s> it is very natural </s>', 46.83077786439316),
#  ('austen', '<s> she was in no hurry at all </s>', 46.866378814143346),
#  ('austen', '<s> there is nothing in that </s>', 47.00049380231161),
#  ('austen', '<s> i will say that for you </s>', 47.208832781143435),
#  ('austen', '<s> and i hope she is well </s>', 47.58424383115093),
#  ('austen', '<s> but how shall i do </s>', 47.5887252968917),
#  ('austen', '<s> yes that he will </s>', 47.89381271039227),
#  ('austen', '<s> it was a very extraordinary thing </s>', 48.04300150645709),
#  ('austen', '<s> i have a great regard for mr perry </s>', 48.16255302900198),
#  ('austen', '<s> you think so do not you </s>', 48.226706708368255),
#  ('austen', '<s> i understand you said elinor </s>', 48.271678414208466),
#  ('austen', '<s> he was quite delighted </s>', 48.30426809740139),
#  ('austen', '<s> i like him very much </s>', 48.7953714631367),
#  ('austen', '<s> it came from mr elliot </s>', 48.8118365076976),
#  ('austen', '<s> she was not obliged to hear </s>', 48.81768776597546),
#  ('austen', '<s> but i thought you would </s>', 48.934261880031585),
#  ('melville', '<s> it is man </s>', 48.96743689438281),
#  ('austen', '<s> you do not mean it </s>', 49.001651239118466),
#  ('austen', '<s> it was not lost on me </s>', 49.0750622051063),
#  ('austen', '<s> but i ought to have gone before </s>', 49.166240220878436),
#  ('austen', '<s> it is not willoughby </s>', 49.256762975800065),
#  ('carroll', '<s> why should it </s>', 49.30033405613657),
#  ('austen',
#   '<s> i have no doubt of his being a most amiable young man </s>',
#   49.45104357198873),
#  ('melville', '<s> but no more of this </s>', 49.50030314773086),
#  ('melville', '<s> i do sir </s>', 49.52233673162972),
#  ('austen', '<s> yes very soon </s>', 49.604164778140046),
#  ('austen', '<s> do not you think so </s>', 49.659094619760964),
#  ('melville', '<s> he must have more than that </s>', 49.814193296231494),
#  ('austen', '<s> no i thank you </s>', 49.87359265119704),
#  ('austen', '<s> very happy to hear it </s>', 49.874343988952546),
#  ('austen', '<s> i am sorry for that </s>', 49.925482733274016),
#  ('austen', '<s> so far it is very true </s>', 50.02358550525387),
#  ('austen', '<s> but so it was </s>', 50.035041104691814),
#  ('austen',
#   '<s> i am glad i have done being in love with him </s>',
#   50.08036524193671),
#  ('austen', '<s> mr elton was only too happy </s>', 50.13673851407021),
#  ('austen',
#   '<s> i am sure lady russell would like him </s>',
#   50.19419140247664),
#  ('austen',
#   '<s> she was not to see frank churchill this morning </s>',
#   50.22757356805869),
#  ('austen', '<s> emma could not resist </s>', 50.75425685564567),
#  ('austen', '<s> but you must go charles </s>', 50.82477963183483),
#  ('austen', '<s> a very fine young man indeed </s>', 50.84081889210679),
#  ('austen', '<s> i am in no hurry </s>', 51.02573454266573),
#  ('austen', '<s> emma could not speak </s>', 51.23191908465744),
#  ('austen', '<s> he is so very superior </s>', 51.268829546545376),
#  ('austen', '<s> emma could not forgive her </s>', 51.27479131409474),
#  ('austen', '<s> i have never been attached to him </s>', 51.32961895595632),
#  ('austen', '<s> do you think i am right </s>', 51.342091213245105),
#  ('austen', '<s> mr elton is going to be married </s>', 51.43716715710995),
#  ('austen', '<s> it is very pretty said mr woodhouse </s>', 51.56106090023771),
#  ('austen',
#   '<s> said i it is miss woodhouse i am sure you will like to see her </s>',
#   51.59340887549191),
#  ('austen',
#   '<s> mrs weston had been speaking to her at the same moment </s>',
#   51.63251287401167),
#  ('austen', '<s> indeed i will </s>', 51.860219861190956),
#  ('austen', '<s> it was a bad business </s>', 51.865323140540504),
#  ('austen', '<s> it was all my doing i know </s>', 51.87422794603803),
#  ('austen', '<s> i do not wonder at you </s>', 52.12808624754723),
#  ('austen', '<s> that i can easily believe </s>', 52.197380544167835),
#  ('austen', '<s> he certainly did </s>', 52.30667392703797),
#  ('austen', '<s> how do you do mr </s>', 52.321591769071006),
#  ('austen', '<s> i am going to kingston </s>', 52.34331720143989),
#  ('austen', '<s> i am afraid none at all </s>', 52.578601290263876),
#  ('austen', '<s> they will hear you </s>', 52.91835805329824),
#  ('austen', '<s> what shall you do </s>', 52.990932933041954),
#  ('austen', '<s> yes i would </s>', 53.052150795147526),
#  ('austen', '<s> mr knightley is not she </s>', 53.05757183659008),
#  ('austen', '<s> but i cannot believe it of you </s>', 53.06350313771953),
#  ('austen', '<s> who could have thought it </s>', 53.12199137621327),
#  ('austen', '<s> i have engaged captain wentworth </s>', 53.26742824341986),
#  ('austen', '<s> elinor told him that it was </s>', 53.33677795421475),
#  ('austen', '<s> elinor could not be cheerful </s>', 53.39575323148656),
#  ('austen',
#   '<s> it would be impossible to go to morrow </s>',
#   53.46281625795449),
#  ('carroll', '<s> what was that </s>', 53.48041170442441),
#  ('austen', '<s> she would not look again </s>', 53.50848339718278),
#  ('austen', '<s> how do you do my dear </s>', 53.52975113290805),
#  ('austen', '<s> i declare i had no idea </s>', 53.61273947506985),
#  ('austen', '<s> mrs weston would be at ease </s>', 53.636068121601724),
#  ('austen', '<s> you must have done well </s>', 53.782541061773536),
#  ('austen', '<s> you may see the end of the house </s>', 53.90158242198406),
#  ('austen', '<s> i hope you are quite well </s>', 53.92189183427963),
#  ('austen', '<s> how sorry i am </s>', 53.94182271311259),
#  ('austen', '<s> yes yes i understand you </s>', 53.99484709488674),
#  ('austen',
#   '<s> said emma as soon as she could speak </s>',
#   54.08931502300821),
#  ('austen',
#   '<s> how do you do very well i thank you </s>',
#   54.095277628281345),
#  ('austen', '<s> mr frank churchill indeed </s>', 54.21088007939411),
#  ('austen', '<s> so much the better </s>', 54.22406986632291),
#  ('austen', '<s> he had an affectionate heart </s>', 54.740105823018986),
#  ('austen', '<s> mr ferrars is to be the man </s>', 54.826267812592015),
#  ('austen',
#   '<s> he asked me if he could do any thing </s>',
#   55.05405674502996),
#  ('melville', '<s> well well well </s>', 55.10215700816726),
#  ('austen', '<s> i am sorry for _her_ </s>', 55.10831618960507),
#  ('austen', '<s> i did not see you before </s>', 55.28595398649552),
#  ('austen', '<s> you will not be hysterical again </s>', 55.33883603094688),
#  ('austen',
#   '<s> anne had a great deal to hear of mr elliot </s>',
#   55.42245956530982),
#  ('austen', '<s> it was not in her nature </s>', 55.48073174264671),
#  ('austen',
#   '<s> i found he had been used to hear of me </s>',
#   55.49453060989927),
#  ('melville', '<s> it was he it was he </s>', 55.53619593545279),
#  ('austen', '<s> i will have nothing to do with it </s>', 55.569861048824514),
#  ('austen', '<s> mr woodhouse told me of it </s>', 55.604620928505916),
#  ('austen', '<s> i have observed it all my life </s>', 55.73986962375036),
#  ('austen',
#   '<s> i have no idea of that sort of thing </s>',
#   55.77013607600334),
#  ('austen', '<s> i have had no hand in it </s>', 55.81541607234041),
#  ('carroll', '<s> i think that will be the best plan </s>', 55.95597410716868),
#  ('austen', '<s> i knew she would </s>', 56.110171008100366),
#  ('austen', '<s> it would never do </s>', 56.32809799768377),
#  ('austen', '<s> i could have no other pleasure </s>', 56.53682790908063),
#  ('austen', '<s> she did not suspect him </s>', 56.66086593198974),
#  ('carroll', '<s> she knows such a very little </s>', 56.94374134958161),
#  ('austen', '<s> no no </s>', 56.9692547536556),
#  ('carroll', '<s> no no </s>', 56.9692547536556),
#  ('carroll', '<s> no no </s>', 56.9692547536556),
#  ('austen',
#   '<s> but i dare say you will go for all that </s>',
#   57.180180527801916),
#  ('austen',
#   '<s> it was what she had been thinking of and wishing to be allowed to do </s>',
#   57.237270976350715),
#  ('melville', '<s> how far off </s>', 57.34305241330869),
#  ('austen', '<s> i shall not attempt it </s>', 57.34745426157892),
#  ('austen', '<s> she did not really like her </s>', 57.350970097720015),
#  ('austen', '<s> i wonder whether it is so </s>', 57.39815840273014),
#  ('austen', '<s> what is all this </s>', 57.48434536133509),
#  ('carroll', '<s> who are you </s>', 57.56614135596556),
#  ('carroll', '<s> who are you </s>', 57.56614135596556),
#  ('austen',
#   '<s> but i have no reason to suppose it so </s>',
#   58.02474198846071),
#  ('austen', '<s> i assured him that i could not </s>', 58.06844813136486),
#  ('austen',
#   '<s> i dare say you are and i am sure i do not at all wonder at it </s>',
#   58.10353117278821),
#  ('austen', '<s> no indeed you are mistaken </s>', 58.103569346196444),
#  ('melville', '<s> tell me that mr </s>', 58.27756517026355),
#  ('austen', '<s> i never could have supposed it </s>', 58.32552933931365),
#  ('austen', '<s> what do you mean </s>', 58.47689856539034),
#  ('austen', '<s> what do you mean </s>', 58.47689856539034),
#  ('austen', '<s> i am not going to marry mr elliot </s>', 58.49723865083314),
#  ('austen',
#   '<s> sir john could not have thought it possible </s>',
#   58.53115854589393),
#  ('austen', '<s> but it should be so no more </s>', 58.537263532681365),
#  ('austen', '<s> that was all very true </s>', 58.560064519279784),
#  ('austen', '<s> that is a great thing </s>', 58.708679196977016),
#  ('austen', '<s> elinor i must go home </s>', 58.82853280554056),
#  ('austen', '<s> mr elton going to be married </s>', 58.88958840551363),
#  ('austen',
#   '<s> she had no scruple with regard to him </s>',
#   59.11623208371743),
#  ('austen',
#   '<s> but it would not do he had not come to the point </s>',
#   59.21603568796365),
#  ('austen', '<s> i was to decide on the best of them </s>', 59.34444497232142),
#  ('austen', '<s> you must indeed you must </s>', 59.50136185036139),
#  ('austen', '<s> i am quite of your opinion </s>', 59.56761189009366),
#  ('austen', '<s> mr frank churchill did not come </s>', 59.64488908726446),
#  ('austen', '<s> where is the young man </s>', 59.65317586745749),
#  ('austen', '<s> his affection was all her own </s>', 59.689899451449186),
#  ('austen', '<s> i was not at all aware of this </s>', 59.70286499778198),
#  ('melville', '<s> what do you know about him </s>', 59.734004427540384),
#  ('austen',
#   '<s> it would not be a bad thing for her to be very much in love with a proper object </s>',
#   60.05957049615539),
#  ('austen',
#   '<s> knightley i could not have believed it </s>',
#   60.49332459240706),
#  ('austen',
#   '<s> no i am sure it is not from the campbells </s>',
#   60.57290778698278),
#  ('austen', '<s> it was done however </s>', 60.584604552346484),
#  ('carroll', '<s> how should i know </s>', 60.616062916767746),
#  ('austen',
#   '<s> i need not tell you what is to be done </s>',
#   60.65274314244627),
#  ('melville', '<s> what is the matter with me </s>', 61.12906597981409),
#  ('austen', '<s> yes yes i see you are </s>', 61.16457111912461),
#  ('austen', '<s> he came to them every day </s>', 61.17516406814998),
#  ('austen',
#   '<s> i am sure i had much rather hear you </s>',
#   61.20457764982062),
#  ('austen', '<s> but i see what you mean </s>', 61.29982333094583),
#  ('austen', '<s> what is the matter </s>', 61.32240935456715),
#  ('austen', '<s> it had been in situation </s>', 61.60378209328834),
#  ('austen', '<s> i like her the better for it </s>', 61.72766422853442),
#  ('austen', '<s> i had not thought of that </s>', 61.892805218434134),
#  ('austen', '<s> i dare say they are sir </s>', 61.91960862961262),
#  ('austen', '<s> i could not have stood it </s>', 61.95877961476955),
#  ('austen', '<s> it was enough for her to feel </s>', 61.97072624241869),
#  ('melville', '<s> they have they have </s>', 62.081454769198984),
#  ('carroll', '<s> oh i know </s>', 62.190544376137645),
#  ('austen', '<s> you understand every thing </s>', 62.232695634661745),
#  ('austen', '<s> it is colonel brandon </s>', 62.25138323498881),
#  ('austen',
#   '<s> she and mr frank churchill had been at weymouth at the same time </s>',
#   62.30571650713847),
#  ('austen', '<s> i would do more than for my own </s>', 62.397301633531846),
#  ('austen',
#   '<s> but you have not seen so much of the world as i have </s>',
#   62.49489117442382),
#  ('austen',
#   '<s> but i am afraid and i should be so very sorry </s>',
#   62.520738293745914),
#  ('austen',
#   '<s> what a very great pleasure it will be to you </s>',
#   62.55281421241292),
#  ('austen',
#   '<s> you are mistaken elinor you are very much mistaken </s>',
#   62.67769978517875),
#  ('austen', '<s> you saw what she said </s>', 62.72208048445342),
#  ('austen', '<s> but i always thought i should </s>', 62.73226744764937),
#  ('austen',
#   '<s> you will allow me to bring jane fairfax </s>',
#   62.83259996790789),
#  ('austen', '<s> what a very good looking man </s>', 62.86714396770121),
#  ('austen', '<s> but she was not wanted to speak </s>', 62.971586001915384),
#  ('austen', '<s> i was there one of the party </s>', 63.25926749874327),
#  ('austen', '<s> mrs elton was spoken of </s>', 63.30741780322002),
#  ('melville', '<s> this is what i mean </s>', 63.359343702499785),
#  ('austen', '<s> she happened to be quite alone </s>', 63.575008900383935),
#  ('austen', '<s> i would have her understand me </s>', 63.85426598865121),
#  ('austen', '<s> no i cannot think that </s>', 64.01798750001211),
#  ('austen', '<s> she did all that i wanted </s>', 64.04442686029621),
#  ('melville', '<s> do with it </s>', 64.09436584173058),
#  ('austen', '<s> i could do very well without it </s>', 64.12574397419824),
#  ('melville', '<s> what is it more </s>', 64.18662570537846),
#  ('austen', '<s> oh yes i dare say you will </s>', 64.20567482633582),
#  ('austen', '<s> i hope i can allow for him </s>', 64.26037287247834),
#  ('austen',
#   '<s> it would have been very unpleasant to me in every respect </s>',
#   64.39846998795694),
#  ('austen',
#   '<s> you will see nothing of it by candlelight </s>',
#   64.68339943861592),
#  ('austen', '<s> you and i need not be afraid </s>', 64.72397146547983),
#  ('austen', '<s> yes i understand the sort of mind </s>', 64.85688103889576),
#  ('austen',
#   '<s> you were all gone i do not know where </s>',
#   64.85983739949789),
#  ('austen', '<s> he might observe that it was so </s>', 64.92742998497468),
#  ('austen', '<s> you will like harriet </s>', 64.9393128132949),
#  ('austen', '<s> she was quite in an agony </s>', 64.99321434644858),
#  ('austen',
#   '<s> indeed that must be a very great pleasure </s>',
#   65.23505905331606),
#  ('austen', '<s> if you will have such ideas </s>', 65.27230448201774),
#  ('austen',
#   '<s> this was very kind of you to be persuaded to come </s>',
#   65.28577438598263),
#  ('austen', '<s> that is a good thing </s>', 65.32649807135618),
#  ('austen',
#   '<s> i hope it is not to say that your sister is worse </s>',
#   65.38926885228672),
#  ('carroll', '<s> the other side of what </s>', 65.43562007388897),
#  ('austen',
#   '<s> and upon my word he is nothing to me </s>',
#   65.67305329866899),
#  ('austen', '<s> my dear madam </s>', 65.79803135954266),
#  ('austen', '<s> my dear madam </s>', 65.79803135954266),
#  ('austen', '<s> elinor would not speak </s>', 65.80607462325835),
#  ('austen',
#   '<s> i never had the smallest i assure you </s>',
#   66.04273995427717),
#  ('austen', '<s> i think lady russell would like him </s>', 66.08940339157559),
#  ('austen',
#   '<s> they had no inclination to listen to her </s>',
#   66.1840312251722),
#  ('austen',
#   '<s> so very obliging of mr frank churchill </s>',
#   66.30951901162308),
#  ('austen',
#   '<s> what say you to mr weston and mr elton </s>',
#   66.32720623536771),
#  ('austen', '<s> it is such a blessing </s>', 66.33975674965701),
#  ('austen', '<s> willoughby was out of the question </s>', 66.35074644651841),
#  ('austen',
#   '<s> it must be very clever or he would not have brought it </s>',
#   66.50103546048524),
#  ('austen', '<s> to be sure so it is </s>', 66.62322403333434),
#  ('austen',
#   '<s> harriet would have been a better match </s>',
#   66.75323543812814),
#  ('austen', '<s> anne could not help laughing </s>', 66.77748008309442),
#  ('austen', '<s> she must not walk </s>', 66.77863391562913),
#  ('austen', '<s> can you indeed </s>', 66.89832627116351),
#  ('austen', '<s> you could not have visited me </s>', 66.90333255251142),
#  ('austen', '<s> my dear it is not like hartfield </s>', 66.92197134805126),
#  ('austen',
#   '<s> i have heard him say that he could listen to her for ever </s>',
#   66.94905715863217),
#  ('austen',
#   '<s> i know it all i know it all cried mrs smith </s>',
#   67.04477810014801),
#  ('austen', '<s> i shall never forget his happiness </s>', 67.05502676948647),
#  ('austen',
#   '<s> but you are too good for that i am sure </s>',
#   67.16617843835029),
#  ('austen', '<s> i could see it in his face </s>', 67.16681327378997),
#  ('austen', '<s> about jane fairfax </s>', 67.45790215273689),
#  ('austen',
#   '<s> she thought of her father of lady russell </s>',
#   67.495268733392),
#  ('austen', '<s> after a short pause </s>', 67.57370961505268),
#  ('austen', '<s> what is mr elliot to me </s>', 67.66565779323918),
#  ('austen', '<s> mr weston had walked in </s>', 67.68247434527387),
#  ('austen', '<s> you remember him i am sure </s>', 68.00907685297467),
#  ('melville', '<s> i think so sir </s>', 68.03764218032931),
#  ('austen',
#   '<s> i hope he will not mind it so very much </s>',
#   68.06989481267738),
#  ('austen',
#   '<s> she was so surprized she did not know what to do </s>',
#   68.12156725754762),
#  ('austen', '<s> i am quite determined to refuse him </s>', 68.17665550768506),
#  ('austen',
#   '<s> i am sure edward ferrars is not well </s>',
#   68.17951688146776),
#  ('austen', '<s> she had not mistaken him </s>', 68.3293187828358),
#  ('austen', '<s> there will not be time for any thing </s>', 68.3509581448318),
#  ('austen',
#   '<s> she wished him to speak but he would not </s>',
#   68.4497055217109),
#  ('austen',
#   '<s> no i do not that is i do not mean what shall i do </s>',
#   68.52847918399527),
#  ('austen', '<s> i do not believe i did you any good </s>', 68.75463351424574),
#  ('austen', '<s> every thing so good </s>', 68.78671279056202),
#  ('austen', '<s> he is always out of humour </s>', 68.88942677316705),
#  ('austen', '<s> it is my party </s>', 68.99532035977566),
#  ('austen', '<s> it is my party </s>', 68.99532035977566),
#  ('austen', '<s> he is going to kingston </s>', 69.03427624111848),
#  ('austen',
#   '<s> there could be no doubt of his being a sensible man </s>',
#   69.11293249016587),
#  ('austen', '<s> but you will do every thing right </s>', 69.14421820948154),
#  ('austen',
#   '<s> how it might be considered by the rest of the party she could not tell </s>',
#   69.21738363518371),
#  ('austen', '<s> now you know all </s>', 69.22028536864349),
#  ('carroll', '<s> it is a very good height indeed </s>', 69.2477830583443),
#  ('melville', '<s> what s that he said </s>', 69.2905580844976),
#  ('austen', '<s> you must come indeed </s>', 69.39131692264505),
#  ('austen',
#   '<s> he had hoped she would speak again but she did not </s>',
#   69.42542605837467),
#  ('austen', '<s> he longed to see her </s>', 69.45063781040072),
#  ('austen',
#   '<s> i understand it was a very handsome letter indeed </s>',
#   69.52037802061386),
#  ('austen', '<s> yes oh </s>', 69.55850768193739),
#  ('austen', '<s> no the young lady to be sure </s>', 69.68635588581822),
#  ('austen',
#   '<s> i do not think it could disagree with you </s>',
#   69.70850998067614),
#  ('austen', '<s> emma my dear emma </s>', 69.84774453156541),
#  ('austen', '<s> what can it be </s>', 69.89231831048022),
#  ('austen', '<s> she wished him not so near her </s>', 70.09492083877348),
#  ('austen',
#   '<s> there is nothing to be compared to it </s>',
#   70.11274895029527),
#  ('austen',
#   '<s> no indeed there was not a hint of mr martin </s>',
#   70.2573049393376),
#  ('austen', '<s> but what is the meaning of this </s>', 70.49440847663995),
#  ('austen',
#   '<s> and mr elliot so anxious that he should </s>',
#   70.51299903729058),
#  ('austen', '<s> he must love her </s>', 70.61508106314221),
#  ('austen', '<s> in half a minute they were together </s>', 70.6734871666539),
#  ('austen',
#   '<s> they had been all in lodgings together </s>',
#   70.73638217068776),
#  ('austen', '<s> i could not stay two minutes </s>', 70.74729753111006),
#  ('austen',
#   '<s> it is frank and miss fairfax said mrs weston </s>',
#   70.76332002676517),
#  ('melville', '<s> it is his </s>', 70.96603029411727),
#  ('melville', '<s> it is his </s>', 70.96603029411727),
#  ('melville', '<s> it is his </s>', 70.96603029411727),
#  ('melville', '<s> it is his </s>', 70.96603029411727),
#  ('melville', '<s> it is his </s>', 70.96603029411727),
#  ('austen', '<s> it is a certainty </s>', 71.01411810166113),
#  ('austen', '<s> what can you suppose </s>', 71.07232702048059),
#  ('austen',
#   '<s> i have the highest opinion in the world of edward s heart </s>',
#   71.1324460717001),
#  ('austen', '<s> and so you are forced to do it </s>', 71.21472827698054),
#  ('austen', '<s> the crofts must be in bath </s>', 71.2883409947659),
#  ('austen',
#   '<s> mrs weston remained with mr woodhouse </s>',
#   71.31226151256854),
#  ('austen', '<s> i am sure they will bring him soon </s>', 71.32062901714293),
#  ('austen',
#   '<s> elinor could not be surprised at their attachment </s>',
#   71.36393501907432),
#  ('austen', '<s> your sister s marriage </s>', 71.44606546422435),
#  ('austen', '<s> i cannot help suspecting him </s>', 71.46876560813504),
#  ('austen', '<s> i care for nothing else </s>', 71.59087350226552),
#  ('austen', '<s> is not it so </s>', 71.64826630973938),
#  ('austen', '<s> i am no dancer </s>', 71.65179604280493),
#  ('austen', '<s> no nothing at all </s>', 71.67931405381636),
#  ('austen', '<s> but still you will be an old maid </s>', 71.86724355001849),
#  ('austen', '<s> in a moment he went on </s>', 71.9004150597375),
#  ('austen',
#   '<s> i am not in the least ashamed of my meaning </s>',
#   71.9474917742233),
#  ('austen',
#   '<s> i would not have mr knightley know any thing about it for the world </s>',
#   71.97349583999853),
#  ('austen', '<s> she thought it was time to make up </s>', 71.97928277032719),
#  ('austen', '<s> he walked by her side </s>', 72.0495908306192),
#  ('austen',
#   '<s> but i thought of her i believe every moment of the day </s>',
#   72.13588020537725),
#  ('austen', '<s> but could it be so </s>', 72.23922384372291),
#  ('carroll', '<s> what do you mean by that </s>', 72.32465307374183),
#  ('austen',
#   '<s> well i wish them happy with all my heart </s>',
#   72.35673698433965),
#  ('austen',
#   '<s> i have a great curiosity to see mrs elton i have heard so much of her </s>',
#   72.3987037206391),
#  ('austen', '<s> but how can it be done </s>', 72.46468698110209),
#  ('austen', '<s> oh did not you </s>', 72.48031359550474),
#  ('austen',
#   '<s> she had been used to affluence it was gone </s>',
#   72.6183031757341),
#  ('austen', '<s> there is no quarrelling with you </s>', 72.71433419728508),
#  ('austen', '<s> indeed you did </s>', 72.74569919905271),
#  ('austen', '<s> the child of good fortune </s>', 72.84047049230189),
#  ('austen', '<s> she is not satisfied </s>', 72.96175455207542),
#  ('austen', '<s> i wish i had looked at him more </s>', 73.04361570884652),
#  ('austen', '<s> she is a sweet creature </s>', 73.08661110567982),
#  ('austen', '<s> how could it be </s>', 73.10565917691504),
#  ('austen',
#   '<s> there could be no doubt of his great pleasure in seeing her </s>',
#   73.15484815226314),
#  ('austen',
#   '<s> i am sure i have not got one half so good </s>',
#   73.15787726534923),
#  ('austen', '<s> he had no concealments with me </s>', 73.27366351709068),
#  ('carroll', '<s> what happened to you </s>', 73.31542580796429),
#  ('austen',
#   '<s> my dear emma i have told you what led me to think of it </s>',
#   73.4372829000924),
#  ('austen',
#   '<s> dear i thought it would have been the death of me </s>',
#   73.5498294305796),
#  ('austen',
#   '<s> i have not the least wish for it i thank you </s>',
#   73.69261001014428),
#  ('austen',
#   '<s> emma knew it to have been very much the case </s>',
#   73.71821967733575),
#  ('carroll',
#   '<s> would you like to see a little of it </s>',
#   73.76167833220042),
#  ('austen', '<s> i beg your pardon </s>', 73.8408209058632),
#  ('carroll', '<s> i beg your pardon </s>', 73.8408209058632),
#  ('austen', '<s> i see how it is said she </s>', 73.90095854420173),
#  ('austen', '<s> i never shall forget his manner </s>', 74.02178678635622),
#  ('austen', '<s> well she is to marry him </s>', 74.09594141439148),
#  ('austen', '<s> so obliging of you </s>', 74.10311049627833),
#  ('austen',
#   '<s> i am much obliged to you was her answer but i am not going with them </s>',
#   74.1387939234626),
#  ('austen', '<s> is not she </s>', 74.22504698213518),
#  ('austen',
#   '<s> he is not at all a well bred young man </s>',
#   74.4917601857405),
#  ('austen',
#   '<s> but mr knightley is so very fine a man </s>',
#   74.49411417289882),
#  ('melville', '<s> tell me not of it </s>', 74.53171952117016),
#  ('austen', '<s> he ought to come said emma </s>', 74.54817339699666),
#  ('austen',
#   '<s> this is what i believe to have happened </s>',
#   74.89587061203183),
#  ('austen', '<s> this was the fact </s>', 74.96872732756697),
#  ('austen', '<s> should not you mr </s>', 75.01410787005685),
#  ('austen',
#   '<s> it would have been strange if i had not gone </s>',
#   75.06790488847415),
#  ('austen', '<s> that is exactly what i said my dear </s>', 75.09743466080047),
#  ('carroll', '<s> it was too late to wish that </s>', 75.15220080921924),
#  ('austen',
#   '<s> it is the greatest amusement in the world </s>',
#   75.22817258984051),
#  ('austen',
#   '<s> but i do not think it is at all a likely thing for him to do </s>',
#   75.27311545479809),
#  ('austen', '<s> what a disappointment it would be </s>', 75.27771320030529),
#  ('melville', '<s> i knew no one in the place </s>', 75.31157512346167),
#  ('austen', '<s> no i did not promise </s>', 75.35086904216472),
#  ('austen',
#   '<s> i began to think i should never see you </s>',
#   75.39661282256341),
#  ('carroll', '<s> i shall be late </s>', 75.40996434112814),
#  ('austen', '<s> poor mrs churchill </s>', 75.49683238078906),
#  ('austen',
#   '<s> he is a most amiable charming young man i believe </s>',
#   75.57717673149078),
#  ('austen',
#   '<s> his mother and sisters were very fond of him </s>',
#   75.64683651998915),
#  ('carroll', '<s> what s in it </s>', 75.69020316565944),
#  ('melville', '<s> and so it was most miserable </s>', 75.69868289073267),
#  ('austen', '<s> it will be the only difference </s>', 75.71327701745703),
#  ('austen', '<s> i had not thought of mrs dixon </s>', 75.77980534259933),
#  ('austen',
#   '<s> i do not know which it ought to be called </s>',
#   75.84475838297455),
#  ('austen',
#   '<s> i wish it could be so easily settled </s>',
#   75.84482214149402),
#  ('austen', '<s> i knew you would wish it </s>', 75.86462904540272),
#  ('austen', '<s> he had not the power of accepting it </s>', 75.8685552415516),
#  ('austen', '<s> mr weston do not mistake me </s>', 75.92766856015744),
#  ('austen', '<s> mrs weston was disappointed </s>', 75.95267696246775),
#  ('melville', '<s> who can tell it </s>', 76.22323631236627),
#  ('carroll', '<s> that s all </s>', 76.251421050116),
#  ('austen', '<s> i was not aware of it myself </s>', 76.29494830954569),
#  ('melville', '<s> no no no </s>', 76.34284130108111),
#  ('austen',
#   '<s> he asked my opinion as to what he was now to do </s>',
#   76.3544717841825),
#  ('austen', '<s> but who is he </s>', 76.52384928932462),
#  ('austen', '<s> i have loved none but you </s>', 76.53326136675129),
#  ('austen',
#   '<s> what is to be done my dear emma what is to be done </s>',
#   76.53442371339848),
#  ('austen',
#   '<s> i do not know who would ever look at him in the company of the other </s>',
#   76.54479141533942),
#  ('austen', '<s> captain wentworth had no fortune </s>', 76.6010382359253),
#  ('austen',
#   '<s> but i know very well what it is and i know where he is too </s>',
#   76.64673473055426),
#  ('austen', '<s> colonel brandon tell you of it </s>', 76.67377845878772),
#  ('austen', '<s> but he told you that he loved you </s>', 76.75872753679064),
#  ('melville', '<s> only one thing could be done </s>', 76.8510408229701),
#  ('austen',
#   '<s> but i am very much and without being at all ashamed of it </s>',
#   76.85195592553164),
#  ('austen', '<s> said almost every body </s>', 76.87143166769478),
#  ('austen',
#   '<s> anne felt that she should like to know who he was </s>',
#   76.88936339281648),
#  ('austen', '<s> i can hardly write </s>', 77.0437856428092),
#  ('austen',
#   '<s> she had seen the same frederick wentworth </s>',
#   77.0481256033638),
#  ('austen', '<s> she was now met by mrs </s>', 77.09417138922572),
#  ('austen',
#   '<s> mr elton certainly did not very well know what to say </s>',
#   77.18799068639753),
#  ('austen',
#   '<s> i am sorry mr and mrs cole should have done it </s>',
#   77.34067986968076),
#  ('austen',
#   '<s> she would be such a delightful companion for emma </s>',
#   77.3761493078678),
#  ('austen', '<s> you will stay and go with us </s>', 77.38168058483318),
#  ('austen',
#   '<s> the appearance of the latter could not be more than the surprise of the moment </s>',
#   77.48376170441108),
#  ('austen', '<s> i am very sure you did me good </s>', 77.68198346881),
#  ('austen', '<s> how is it possible </s>', 77.72585690530249),
#  ('austen', '<s> nothing can be like it to be sure </s>', 77.85442398399702),
#  ('austen',
#   '<s> i am forgetting that i am not acquainted with her </s>',
#   77.8643072760169),
#  ('austen', '<s> i can give you no account of them </s>', 77.87450294439437),
#  ('austen',
#   '<s> i am going home and you have an engagement with your friend </s>',
#   77.92626318226735),
#  ('austen', '<s> it was an unaccountable business </s>', 77.93888203779782),
#  ('austen',
#   '<s> she was sure that he had not been happy in marriage </s>',
#   77.96847844800018),
#  ('austen', '<s> i will carry her myself </s>', 77.98895733371276),
#  ('austen',
#   '<s> i suppose you will not like to call at the great house before they have been to see you </s>',
#   78.02146991874444),
#  ('austen',
#   '<s> if we could be certain that it would be only for a while </s>',
#   78.33082372868478),
#  ('austen', '<s> i had been unguarded </s>', 78.46706954136839),
#  ('austen',
#   '<s> mr elton must now be left to himself </s>',
#   78.52810286778063),
#  ('austen', '<s> she was obliged to stop and think </s>', 78.55916459146091),
#  ('melville', '<s> do i suppose it </s>', 78.93515889392711),
#  ('melville', '<s> what do you want of me </s>', 79.19151744998098),
#  ('austen',
#   '<s> yes i have no doubt of her being extremely attached to him </s>',
#   79.31804156050185),
#  ('austen',
#   '<s> mr elton in love with me what an idea </s>',
#   79.33210857962399),
#  ('austen',
#   '<s> i am very much obliged to you said emma laughing again </s>',
#   79.5353256068731),
#  ('austen', '<s> marianne was softened in a moment </s>', 79.57556779106808),
#  ('austen', '<s> had been a question of his </s>', 79.68681106596107),
#  ('austen',
#   '<s> we were always glad to see him at hartfield </s>',
#   79.79566704696659),
#  ('austen', '<s> aye to be sure </s>', 79.84933481170876),
#  ('austen',
#   '<s> i hope he will be more agreeable now </s>',
#   79.87059130801308),
#  ('austen', '<s> no there is but one </s>', 79.97200811427447),
#  ('austen', '<s> do you think him so very plain </s>', 80.06400402240634),
#  ('austen', '<s> said mrs musgrove to mrs croft </s>', 80.08948169485937),
#  ('austen', '<s> i met him just now </s>', 80.19635198728058),
#  ('austen',
#   '<s> yes and i shall be very happy in his acquaintance </s>',
#   80.253389904517),
#  ('austen', '<s> a knock at the door </s>', 80.28782224168707),
#  ('austen', '<s> no not now i thank you </s>', 80.3207642222708),
#  ('austen',
#   '<s> i have a very sincere interest in emma </s>',
#   80.34589352758017),
#  ('austen', '<s> ah well </s>', 80.3840148969006),
#  ('carroll', '<s> ah well </s>', 80.3840148969006),
#  ('austen', '<s> there i was quite right </s>', 80.56824623771321),
#  ('austen', '<s> she will be mistaken however </s>', 80.73241827713224),
#  ('melville', '<s> but i do not mean anything sir </s>', 80.79099394287685),
#  ('austen',
#   '<s> it must have been about the same time that he became known to my father and sister </s>',
#   80.89717783395174),
#  ('austen', '<s> i will not abuse him </s>', 80.90702386162049),
#  ('austen', '<s> well i am so sorry oh </s>', 80.91076939970172),
#  ('austen',
#   '<s> it was a great satisfaction to us to hear it i assure you </s>',
#   80.96507226547551),
#  ('austen',
#   '<s> he must have a pretty good opinion of himself </s>',
#   81.00195817572572),
#  ('austen', '<s> yes said emma i hope i do </s>', 81.02212477232136),
#  ('austen', '<s> thank you ma am said elinor </s>', 81.14314771144866),
#  ('austen',
#   '<s> but then it had been taken up by his father and mother </s>',
#   81.17148506173643),
#  ('austen', '<s> the ladies were all at home </s>', 81.21473270096014),
#  ('austen', '<s> indeed i do say it </s>', 81.27347986365079),
#  ('austen', '<s> are you quite sure of it </s>', 81.28409981418406),
#  ('austen',
#   '<s> mr elton is a very pretty young man to be sure and a very good young man and i have a great regard for him </s>',
#   81.30668260500316),
#  ('austen',
#   '<s> you have been long acquainted with colonel brandon have not you </s>',
#   81.34639735415297),
#  ('austen', '<s> it did torture me </s>', 81.37520194323254),
#  ('austen',
#   '<s> i dare say mr knightley will be so kind as to meet him </s>',
#   81.38321319486465),
#  ('austen', '<s> i am tired of doing nothing </s>', 81.44537733791809),
#  ('austen', '<s> how fond he was of it </s>', 81.47004330524634),
#  ('austen', '<s> yes perhaps it had been mr elliot </s>', 81.50443717248287),
#  ('austen', '<s> and i think she feels it </s>', 81.6743037675855),
#  ('melville', '<s> i quaked to think of it </s>', 81.71382585875081),
#  ('austen',
#   '<s> he could not believe her to be encouraging him </s>',
#   81.84458302268217),
#  ('austen',
#   '<s> it could not be very lasting however </s>',
#   81.94766615979707),
#  ('austen',
#   '<s> i would give anything to know the truth of it </s>',
#   82.0230888379483),
#  ('austen',
#   '<s> i am by no means assured of his regard for me </s>',
#   82.06901821419028),
#  ('carroll', '<s> is that all </s>', 82.09993784878267),
#  ('austen',
#   '<s> i am sure you were of use to me cried emma </s>',
#   82.13859568479981),
#  ('austen',
#   '<s> i want you to talk about me to mr elliot </s>',
#   82.15283963261133),
#  ('austen',
#   '<s> i hope you will be a great deal at combe magna </s>',
#   82.2507697236085),
#  ('austen',
#   '<s> perhaps you may not have heard that he is married </s>',
#   82.3407496175993),
#  ('austen', '<s> what is this </s>', 82.40446104606326),
#  ('austen', '<s> i am concerned to hear of it </s>', 82.45263021979294),
#  ('austen', '<s> we shall not be many you know </s>', 82.54531864059553),
#  ('austen',
#   '<s> emma had as much reason to be satisfied with the rest of the party as with mr knightley </s>',
#   82.55662195872405),
#  ('austen', '<s> what is the gentleman s name </s>', 82.68787697687807),
#  ('austen',
#   '<s> i have a great curiosity to know what mr elliot was as a very young man </s>',
#   82.7019548036877),
#  ('melville', '<s> how was it </s>', 82.71686505053347),
#  ('austen', '<s> aye very true </s>', 82.79628480146995),
#  ('austen', '<s> but mr elliot was not done with </s>', 82.91491779636395),
#  ('austen',
#   '<s> i do not know any body who draws so well as you do </s>',
#   82.91703550871317),
#  ('austen',
#   '<s> she therefore said no more for some time </s>',
#   82.93648671029084),
#  ('austen', '<s> yes that of course </s>', 82.9647897549705),
#  ('austen', '<s> you will never guess </s>', 83.2040257148221),
#  ('austen', '<s> all looked up to them </s>', 83.23461558041757),
#  ('austen', '<s> if she has it now you have given it </s>', 83.28652272471118),
#  ('austen', '<s> why should you think so </s>', 83.37156417404155),
#  ('austen',
#   '<s> such a woman as i am sure fanny will be glad to know </s>',
#   83.45557199339002),
#  ('austen',
#   '<s> a very agreeable young man to be sure i know him very well </s>',
#   83.48501211362587),
#  ('austen', '<s> i believe she does </s>', 83.49681502114457),
#  ('austen', '<s> she was not sorry for the excuse </s>', 83.56660414514013),
#  ('austen', '<s> and a delightful dance it was to be </s>', 83.65806957387188),
#  ('austen', '<s> that is very likely </s>', 83.73685680915287),
#  ('austen',
#   '<s> and you really are not engaged to him </s>',
#   83.8525476363165),
#  ('carroll', '<s> you are not attending </s>', 83.97964717861676),
#  ('austen', '<s> she must not appear at first </s>', 83.99680336963681),
#  ('austen', '<s> it does not bear talking of </s>', 84.01345069065255),
#  ('austen',
#   '<s> she did not imagine that her father had at present an idea of the kind </s>',
#   84.0170886454287),
#  ('austen',
#   '<s> if you had seen her as i did when she was at the worst </s>',
#   84.02945627219944),
#  ('austen',
#   '<s> and i believe marianne will be the most happy with him of the two </s>',
#   84.08557586757375),
#  ('austen',
#   '<s> she was not so easily to be talked out of it </s>',
#   84.08719058364775),
#  ('austen', '<s> you are not serious </s>', 84.18376552694056),
#  ('austen',
#   '<s> she has been so kind as to promise it </s>',
#   84.26101891433149),
#  ('austen', '<s> but did you never see him </s>', 84.46563736235147),
#  ('austen', '<s> do you think it will look well </s>', 84.65575420803444),
#  ('austen',
#   '<s> i am sure i must have been as white as my gown </s>',
#   84.68865416826876),
#  ('carroll', '<s> how can i have done that </s>', 84.6899792230875),
#  ('austen', '<s> can you ma am </s>', 84.71627395345014),
#  ('carroll',
#   '<s> there was certainly too much of it in the air </s>',
#   84.80307910991029),
#  ('carroll',
#   '<s> she said to herself in a melancholy tone </s>',
#   84.84292793891132),
#  ('austen',
# ...
#   95.758589206438),
#  ('austen', '<s> i knew how soon he would come </s>', 95.76233433662202),
#  ('austen', '<s> what is the matter now </s>', 95.8034549579534),
#  ('melville', '<s> the circumstance was this </s>', 95.83324780357341),
#  ('austen',
#   '<s> i am afraid ma am that it is not perfectly understood </s>',
#   95.91032530493628),
#  ('austen',
#   '<s> she must be attached to you or she would not have married you </s>',
#   95.94037924676368),
#  ('austen', '<s> they may be induced to go too </s>', 95.96941509042108),
#  ('austen',
#   '<s> her influence would have been enough </s>',
#   96.01629974630441),
#  ('austen', '<s> they were obliged to move </s>', 96.11891491674533),
#  ('austen',
#   '<s> yes said john knightley and i think we shall have a good deal of it </s>',
#   96.14131136697688),
#  ('austen', '<s> i will not say quite all </s>', 96.16048219208527),
#  ('austen',
#   '<s> he is as well acquainted with his own claims as you can be with harriet s </s>',
#   96.22656263911762),
#  ('austen', '<s> oh don t think of me </s>', 96.23949831786375),
#  ('austen',
#   '<s> no to be sure you could not but i never thought of that before </s>',
#   96.26699629193274),
#  ('austen', '<s> but i shall see them tomorrow </s>', 96.38589508192155),
#  ('austen', '<s> i never met with her equal </s>', 96.40024457584006),
#  ('austen', '<s> we thought you were to bring them </s>', 96.51587888999494),
#  ('austen', '<s> the others will be here presently </s>', 96.53199699520482),
#  ('austen',
#   '<s> mr woodhouse was almost as glad to see him now as he would have been sorry to see him before </s>',
#   96.55930915880289),
#  ('austen', '<s> i shall be no support to mrs weston </s>', 96.57039402669939),
#  ('austen', '<s> we seemed to understand each other </s>', 96.58599075628263),
#  ('austen',
#   '<s> she looked back as well as she could but it was all confusion </s>',
#   96.62924385578035),
#  ('austen', '<s> he certainly loved her </s>', 96.6443869166625),
#  ('austen',
#   '<s> i should be extremely sorry to be giving them any pain </s>',
#   96.67356694597018),
#  ('austen',
#   '<s> i know they will but i am sure i would not do such a thing for all the world la </s>',
#   96.69379706819711),
#  ('austen', '<s> yes we do know it all </s>', 96.70899077390092),
#  ('carroll', '<s> who cares for you </s>', 96.83052467248956),
#  ('melville', '<s> and he knows it too </s>', 96.88409762236688),
#  ('austen', '<s> it was her superior duty </s>', 96.91845851584222),
#  ('austen', '<s> said he at last </s>', 96.93369970375673),
#  ('austen',
#   '<s> said colonel brandon there is indeed </s>',
#   97.34393775137907),
#  ('austen',
#   '<s> it would be incompatible with what she owed to her father and with what she felt for him </s>',
#   97.49718433650634),
#  ('austen',
#   '<s> woodhouse i am so glad to hear such a good account </s>',
#   97.50199406040753),
#  ('austen',
#   '<s> but they ought to call upon you as soon as possible </s>',
#   97.57853305570869),
#  ('austen', '<s> she thinks nobody equal to him </s>', 97.60971805247917),
#  ('austen',
#   '<s> i do not understand what you mean by success said mr knightley </s>',
#   97.63515671494186),
#  ('austen',
#   '<s> it must be a severe trial to them all </s>',
#   97.65834324970683),
#  ('austen', '<s> you know who i mean </s>', 97.66272515122212),
#  ('austen',
#   '<s> i have often talked to her a good deal </s>',
#   97.67337073895698),
#  ('austen', '<s> it is mrs dixon i dare say </s>', 97.72945513026836),
#  ('austen', '<s> how much may not a few months do </s>', 97.76129414503512),
#  ('austen',
#   '<s> but i think my dear you said you had got it </s>',
#   97.86866671373097),
#  ('austen',
#   '<s> lady russell was now perfectly decided in her opinion of mr elliot </s>',
#   97.87414984689948),
#  ('austen',
#   '<s> but first of all you must tell me the name of the young lady i am going to talk about </s>',
#   97.89865325961894),
#  ('austen', '<s> i am a great dreamer </s>', 97.92684612103379),
#  ('austen', '<s> such a home indeed </s>', 97.96974245739715),
#  ('austen',
#   '<s> i do not ask whether you are musical mrs elton </s>',
#   97.98107759223512),
#  ('austen',
#   '<s> it would be the natural result of your affection for her </s>',
#   98.0342985061791),
#  ('austen', '<s> yes yes that in particular </s>', 98.05801124088462),
#  ('austen',
#   '<s> but i assure you i have never been in the house above twice in my life </s>',
#   98.0831265228539),
#  ('austen',
#   '<s> he is very far from being independent </s>',
#   98.15952985119257),
#  ('austen', '<s> but it is even so </s>', 98.20177647265699),
#  ('austen', '<s> aye my dear that i do indeed </s>', 98.28080471653979),
#  ('austen',
#   '<s> i have been considering what we had best do </s>',
#   98.32224582175414),
#  ('austen',
#   '<s> she thinks so little of her own beauty </s>',
#   98.33804922278345),
#  ('austen',
#   '<s> she could never see a fault in any of them </s>',
#   98.37658527491112),
#  ('austen', '<s> i wonder what will become of her </s>', 98.64177860569374),
#  ('austen',
#   '<s> so obliged to you for the carriage last night </s>',
#   98.65561834844954),
#  ('austen', '<s> i did invite him you know </s>', 98.71305373583795),
#  ('austen', '<s> i know nothing of the picturesque </s>', 98.79409040021883),
#  ('austen', '<s> he sat by her at dinner </s>', 98.83371549027555),
#  ('melville', '<s> it has happened before </s>', 98.91235267284563),
#  ('austen',
#   '<s> and so i shall always say my dear you may depend on it </s>',
#   98.91406075064594),
#  ('austen', '<s> it is a retired place </s>', 98.97241836960899),
#  ('austen',
#   '<s> she read nothing but what they had been used to read together </s>',
#   99.00212194018656),
#  ('austen', '<s> we are never safe from him </s>', 99.13067509948522),
#  ('austen',
#   '<s> i have a very strong notion that it comes from him </s>',
#   99.17133922656656),
#  ('austen', '<s> by all means </s>', 99.21202507617994),
#  ('austen', '<s> he is no hypocrite now </s>', 99.2253655826642),
#  ('austen', '<s> i wish i were anywhere else </s>', 99.22632071921898),
#  ('austen',
#   '<s> he will have her at last aye that he will </s>',
#   99.63843020417954),
#  ('austen',
#   '<s> i do not expect my children to be asked you know </s>',
#   99.86287057146822),
#  ('austen',
#   '<s> miss woodhouse looks as if she did not want me </s>',
#   99.90853293858264),
#  ('austen', '<s> i am not prejudiced </s>', 99.91659610719238),
#  ('austen',
#   '<s> was mr ferrars in the carriage with her </s>',
#   100.21186871307756),
#  ('austen', '<s> i really think they ought </s>', 100.25207160470335),
#  ('austen',
#   '<s> i should like to know why you imagine i am </s>',
#   100.25597157473888),
#  ('austen', '<s> i have no pity for either of them </s>', 100.27132733903453),
#  ('austen',
#   '<s> it was not the gipsies it was not mr frank churchill that i meant </s>',
#   100.37297960918114),
#  ('austen',
#   '<s> he had passed out of the room without a look </s>',
#   100.37416440758464),
#  ('austen',
#   '<s> you would not have been so long in coming if you had had a pleasant idea of highbury </s>',
#   100.44114724950845),
#  ('austen',
#   '<s> he was determined to make it by marriage </s>',
#   100.44787391185447),
#  ('austen', '<s> there it is done </s>', 100.61128907690664),
#  ('austen',
#   '<s> mr weston s ball was to be a real thing </s>',
#   100.6313787223201),
#  ('austen', '<s> but i would not alarm you too much </s>', 100.6328458311162),
#  ('austen', '<s> do take it to your sister </s>', 100.75796948450004),
#  ('austen',
#   '<s> but it appears i should hope it would be a very happy match </s>',
#   100.79329391573782),
#  ('austen',
#   '<s> i will take it home with me at night </s>',
#   101.04574250824423),
#  ('austen',
#   '<s> and mrs weston is so anxious to be acquainted with him that she must be almost as happy as yourself </s>',
#   101.10578333483744),
#  ('austen', '<s> not quite a few lines more </s>', 101.23340053204988),
#  ('austen',
#   '<s> but i cannot imagine how i could be so off my guard </s>',
#   101.23924251266264),
#  ('austen',
#   '<s> i had not thought of it before but that is the best way </s>',
#   101.24971214835043),
#  ('austen',
#   '<s> there is no comparison between them </s>',
#   101.36573165954222),
#  ('austen',
#   '<s> said she beginning again when they were all in the street </s>',
#   101.40328098904583),
#  ('melville', '<s> what shall i say to him first </s>', 101.42570606731373),
#  ('austen',
#   '<s> i have not a doubt of it said marianne and i have nothing to regret nothing but my own folly </s>',
#   101.57851901773115),
#  ('austen',
#   '<s> nothing could have done it away to my feelings </s>',
#   101.68687976666547),
#  ('austen', '<s> the past was nothing </s>', 101.81854601781083),
#  ('austen',
#   '<s> you have been here only to be useful </s>',
#   101.84265954450517),
#  ('austen', '<s> leave it to me </s>', 101.87675398212886),
#  ('austen',
#   '<s> captain wentworth must be out of sight </s>',
#   101.93938275005983),
#  ('carroll',
#   '<s> i do wonder what can have happened to me </s>',
#   102.03069027688589),
#  ('austen', '<s> i never was in better health </s>', 102.0600646035212),
#  ('austen',
#   '<s> he was not a great favourite with his fair sister in law </s>',
#   102.2666594806938),
#  ('austen', '<s> i never was equal to this </s>', 102.2857470342174),
#  ('austen', '<s> they have no mercy on her </s>', 102.39487781406213),
#  ('austen', '<s> do not you anne </s>', 102.48544227044178),
#  ('austen', '<s> but she does every thing well </s>', 102.57274645286374),
#  ('austen',
#   '<s> i assure you i have no doubt of its doing mr woodhouse good </s>',
#   102.57488062045326),
#  ('austen',
#   '<s> i am very glad you did and that you communicated it to me </s>',
#   102.5899612274183),
#  ('austen',
#   '<s> it was soon uppercross with him almost every day </s>',
#   102.59361380363875),
#  ('austen', '<s> i shall press you no more </s>', 102.69968304155549),
#  ('austen', '<s> and yet it is not very unlikely </s>', 102.70544736558166),
#  ('melville', '<s> aye aye it must be so </s>', 102.82869703626805),
#  ('austen',
#   '<s> they were more in love with him yet there it was not love </s>',
#   102.88393830530121),
#  ('carroll', '<s> he said to the queen </s>', 102.90061938722324),
#  ('austen',
#   '<s> mrs weston laughed and said he did not know what he was talking about </s>',
#   102.99868874348765),
#  ('melville', '<s> what s the matter with you </s>', 103.19627491913471),
#  ('melville', '<s> it was thus now </s>', 103.33917852634336),
#  ('austen', '<s> gone to mr woodhouse s </s>', 103.4231269991514),
#  ('austen', '<s> you spent the evening with mrs </s>', 103.59526639539185),
#  ('austen', '<s> leave it all to me </s>', 103.60311577136306),
#  ('austen', '<s> but what are you in doubt of </s>', 103.74527055441797),
#  ('austen', '<s> should not you marianne </s>', 103.87242088797278),
#  ('melville', '<s> no sooner sir </s>', 103.87349823280195),
#  ('austen',
#   '<s> lady russell could not help laughing </s>',
#   104.01593451467836),
#  ('austen', '<s> mr elton knows you </s>', 104.020598694411),
#  ('austen',
#   '<s> and you may say that i mean to call upon her soon </s>',
#   104.10130451283229),
#  ('austen',
#   '<s> but it was more probable that he should be come to stay </s>',
#   104.16855667197628),
#  ('austen',
#   '<s> mr knightley might quarrel with her but emma could not quarrel with herself </s>',
#   104.16977122971764),
#  ('austen',
#   '<s> i cannot agree with you there said elinor </s>',
#   104.17429964012992),
#  ('austen', '<s> you will not like the noise </s>', 104.18209741601365),
#  ('austen',
#   '<s> she was extremely angry with herself </s>',
#   104.21310141662963),
#  ('austen', '<s> he wished to avoid seeing her </s>', 104.24126466716494),
#  ('austen',
#   '<s> no indeed i have no doubts at all on that head </s>',
#   104.27143686008525),
#  ('austen',
#   '<s> but you will not give me your advice miss dashwood </s>',
#   104.29150169182883),
#  ('austen', '<s> it is his own idea </s>', 104.30536266932005),
#  ('austen', '<s> what is the amount of his fortune </s>', 104.41941731968194),
#  ('melville', '<s> oh the world </s>', 104.60929489147347),
#  ('austen', '<s> it might be him perhaps </s>', 104.73646354095979),
#  ('austen', '<s> and then not to find him at home </s>', 104.79371523974326),
#  ('austen',
#   '<s> if he would be so good as to read to them it would be a kindness indeed </s>',
#   104.84508547080023),
#  ('austen',
#   '<s> i never was more astonished in my life </s>',
#   104.93958695906322),
#  ('austen',
#   '<s> he felt the going away almost too much to speak of it </s>',
#   105.03463057873276),
#  ('austen',
#   '<s> lady middleton was equally pleased with mrs dashwood </s>',
#   105.14969997321488),
#  ('austen',
#   '<s> you must have seen the difference as well as i </s>',
#   105.17123174900044),
#  ('austen', '<s> said mr weston looking about </s>', 105.19115994212564),
#  ('austen',
#   '<s> she had no doubt of what mr weston was often thinking about </s>',
#   105.21360301312866),
#  ('austen',
#   '<s> do you think he had the elliot countenance </s>',
#   105.23927595830551),
#  ('austen',
#   '<s> i cannot suppose it possible that she should </s>',
#   105.3649425491241),
#  ('austen',
#   '<s> i shall therefore set off to morrow </s>',
#   105.37519274962715),
#  ('austen', '<s> i shall leave you together </s>', 105.39240862931098),
#  ('austen', '<s> i can hardly tell myself </s>', 105.49643358313958),
#  ('austen',
#   '<s> i believe it is very true my dear indeed said mr woodhouse with a sigh </s>',
#   105.56707241573098),
#  ('austen',
#   '<s> in her own room she tried to comprehend it </s>',
#   105.63883465499997),
#  ('austen', '<s> what did you hear </s>', 105.64053765241728),
#  ('austen',
#   '<s> she found something else must be done </s>',
#   105.64260551915088),
#  ('austen',
#   '<s> i am not at all surprized that he should have fallen in love </s>',
#   105.66591233034387),
#  ('austen', '<s> it seems but the work of a moment </s>', 105.69001952072125),
#  ('austen',
#   '<s> i am sure i was very much surprized when i first heard she was going to be married </s>',
#   105.77018589518055),
#  ('austen',
#   '<s> no i have not i know nothing pray tell me </s>',
#   105.78074414695713),
#  ('austen',
#   '<s> but you do not consider how it may appear to the coles </s>',
#   105.88773057904545),
#  ('austen', '<s> in a few months my dear marianne </s>', 106.00068206584449),
#  ('austen',
#   '<s> i had quite determined to go away again </s>',
#   106.01417161391025),
#  ('austen',
#   '<s> they will be delighted to come to morrow evening </s>',
#   106.12505090161395),
#  ('austen',
#   '<s> i did not know that i had fixed a day but as he says i did i am going now </s>',
#   106.1306812327931),
#  ('melville', '<s> that s it that s it </s>', 106.14446041197017),
#  ('melville', '<s> that s it that s it </s>', 106.14446041197017),
#  ('austen',
#   '<s> i was sure that would come out if it was so </s>',
#   106.23142505422415),
#  ('melville', '<s> it was a wondrous sight </s>', 106.23351360210143),
#  ('austen',
#   '<s> poor young man and what is to become of him </s>',
#   106.27441209186145),
#  ('austen',
#   '<s> you do us a great deal of honour to day i am sure </s>',
#   106.31150574094166),
#  ('austen',
#   '<s> it was her very particular friend you know </s>',
#   106.32744721424619),
#  ('austen',
#   '<s> i had not recollected it before i declare but it must be very bad </s>',
#   106.37862757483045),
#  ('austen',
#   '<s> such a letter was not to be soon recovered from </s>',
#   106.41615622933914),
#  ('austen', '<s> i am quite ready </s>', 106.52180250377789),
#  ('carroll',
#   '<s> i think i may as well go in at once </s>',
#   106.63476759563777),
#  ('austen',
#   '<s> mrs dashwood smiled and said nothing </s>',
#   106.68792872650495),
#  ('austen',
#   '<s> i have not nerves for the sort of thing </s>',
#   106.7726866640644),
#  ('austen', '<s> it is so ridiculous </s>', 106.77603201079644),
#  ('austen',
#   '<s> he is a man said lady russell whom i have no wish to see </s>',
#   106.79798620338086),
#  ('austen', '<s> i shall not scold you </s>', 106.8125508466013),
#  ('melville', '<s> i must have partners </s>', 106.8207110030752),
#  ('austen',
#   '<s> i never could have an idea of any body else and so i thought you knew </s>',
#   106.87427330607382),
#  ...]

# %% [markdown]
# # iterate
#
# this is meant to be an iterative algorithm, so we add the top sentences (using threshold) to the original training data, make a new language model, and calculate new perplexity scores over the outside data.

# %%
iters = 500

add_corpus = corpus[:]       # the expanding id-corpus
rem_unlabeled = unlabeled[:] # the shrinking unlabeled data
additions = []               # track additions to lm corpus
threshhold = 100.0           # perplexity threshhold
cutoff = 25                  # cutoff for added sents, make large to 'ignore'
k = 0.001                    # smoothing term for perplexity add-k smoothing

for i in range(iters):
    
    # EarlyStopping
    cnt = 0
    
    # indices to remove from unlabeled data
    remove_idx = []
    
    # build language model
    vocabsize, vocab_counts, bigram_counts = languagemodel(add_corpus)
    
    # rank perplexities
    perplexities = [perplexity(s[1], k) for s in rem_unlabeled]
    
    # take top sents
    add = 0
    for idx, perp in enumerate(perplexities):
        if perp < threshhold:
            additions.append(rem_unlabeled[idx])
            add_corpus.append(rem_unlabeled[idx][1])
            remove_idx.append(idx)
            cnt += 1
            add += 1
        if add == cutoff:
            break
    
    # filter out additions
    rem_unlabeled = [rem_unlabeled[i] for i in range(len(rem_unlabeled)) if i not in remove_idx]
    
    # if no added sents, terminate
    if cnt == 0:
        print("no added sentences, stopping...\n")
        debug = [(x[0], ' '.join(x[1]), y) for x, y in sorted(zip(rem_unlabeled, perplexities), key=lambda pair: pair[1])][:100]
        for d in debug[:10]:
            print(d)
        break
    
    if i > 0 and i % 10 == 0:
        print("iter", i, ": total added", len(additions), "sents")
# Out:
# iter 10 : total added 275 sents
# iter 20 : total added 525 sents
# iter 30 : total added 775 sents
# iter 40 : total added 1025 sents
# iter 50 : total added 1275 sents
# iter 60 : total added 1525 sents
# iter 70 : total added 1775 sents
# iter 80 : total added 2025 sents
# no added sentences, stopping...
#
# ('melville', '<s> i do not think that any sensation lurks in it </s>', 100.19508495878277)
# ('austen', '<s> the consequence said she has been a state of perpetual suffering to me and so it ought </s>', 100.55487042161359)
# ('austen', '<s> no no no how can you suspect me of such a thing </s>', 100.73587402614565)
# ('austen', '<s> there was much to regret </s>', 100.73615839319187)
# ('melville', '<s> he snorts to think of it </s>', 100.84287118187619)
# ('austen', '<s> it is time for us to be going indeed </s>', 100.98943711050511)
# ('austen', '<s> said i i cannot think who you mean </s>', 101.22991326463982)
# ('austen', '<s> i hope i know better now than to care for mr martin or to be suspected of it </s>', 101.36259917363314)
# ('austen', '<s> however i got a very good husband and i don t know what the greatest beauty can do more </s>', 101.38862668489135)
# ('austen', '<s> don t disturb him </s>', 101.39097546526071)

# %% [markdown]
# ## evaluation

# %%
diff = len(add_corpus) - len(corpus)
totl = len(unlabeled)
print("sents found:", diff, "(%", diff*100/totl, "of unlabeled)")
# Out:
# sents found: 2157 (% 9.817486686996496 of unlabeled)

# %%
labels = [t[0] for t in additions]
corrects = [t[0] for t in additions if t[0]=='austen']
print("precision of found sents: ", len(corrects)/len(labels))
# Out:
# precision of found sents:  0.9058878071395456

# %%
recall = len(corrects)/len(withheld)
print("recall of unlabeled austen sents: ", recall)
# Out:
# recall of unlabeled austen sents:  0.16844827586206895
